# %% [markdown]
# Please note that this notebook is intended to be run in Google Colab rather than as a Jupyter notebook on your local machine. Please click the "Open in Colab" button.

# %% [markdown]
# # Setup

# %%
# !pip install chemprop
# !pip install rdkit-pypi  # should be included in above after Chemprop v1.6 release
# Out:
# Requirement already satisfied: chemprop in c:\users\noviasari\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: flask>=1.1.2 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (2.2.2)
# Requirement already satisfied: hyperopt>=0.2.3 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (0.2.7)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (3.7.2)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (1.24.3)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (2.0.3)
# Requirement already satisfied: pandas-flavor>=0.2.0 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (0.6.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (1.3.0)
# Requirement already satisfied: sphinx>=3.1.2 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (5.0.2)
# Requirement already satisfied: tensorboardX>=2.0 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (2.6.2.2)
# Requirement already satisfied: torch>=1.4.0 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (2.2.2)
# Requirement already satisfied: tqdm>=4.45.0 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (4.65.0)
# Requirement already satisfied: typed-argument-parser>=1.6.1 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (1.10.0)
# Requirement already satisfied: rdkit>=2020.03.1.0 in c:\users\noviasari\anaconda3\lib\site-packages (from chemprop) (2023.9.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\noviasari\anaconda3\lib\site-packages (from flask>=1.1.2->chemprop) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\noviasari\anaconda3\lib\site-packages (from flask>=1.1.2->chemprop) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\noviasari\anaconda3\lib\site-packages (from flask>=1.1.2->chemprop) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\noviasari\anaconda3\lib\site-packages (from flask>=1.1.2->chemprop) (8.0.4)
# Requirement already satisfied: scipy in c:\users\noviasari\anaconda3\lib\site-packages (from hyperopt>=0.2.3->chemprop) (1.11.1)
# Requirement already satisfied: six in c:\users\noviasari\appdata\roaming\python\python311\site-packages (from hyperopt>=0.2.3->chemprop) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\noviasari\anaconda3\lib\site-packages (from hyperopt>=0.2.3->chemprop) (3.1)
# Requirement already satisfied: future in c:\users\noviasari\anaconda3\lib\site-packages (from hyperopt>=0.2.3->chemprop) (0.18.3)
# Requirement already satisfied: cloudpickle in c:\users\noviasari\anaconda3\lib\site-packages (from hyperopt>=0.2.3->chemprop) (2.2.1)
# Requirement already satisfied: py4j in c:\users\noviasari\anaconda3\lib\site-packages (from hyperopt>=0.2.3->chemprop) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\noviasari\anaconda3\lib\site-packages (from matplotlib>=3.1.3->chemprop) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\noviasari\anaconda3\lib\site-packages (from matplotlib>=3.1.3->chemprop) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\noviasari\anaconda3\lib\site-packages (from matplotlib>=3.1.3->chemprop) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\noviasari\anaconda3\lib\site-packages (from matplotlib>=3.1.3->chemprop) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\noviasari\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.3->chemprop) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\noviasari\anaconda3\lib\site-packages (from matplotlib>=3.1.3->chemprop) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\noviasari\anaconda3\lib\site-packages (from matplotlib>=3.1.3->chemprop) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\noviasari\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.3->chemprop) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\noviasari\anaconda3\lib\site-packages (from pandas>=1.0.3->chemprop) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\noviasari\anaconda3\lib\site-packages (from pandas>=1.0.3->chemprop) (2023.3)
# Requirement already satisfied: xarray in c:\users\noviasari\anaconda3\lib\site-packages (from pandas-flavor>=0.2.0->chemprop) (2023.6.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\noviasari\anaconda3\lib\site-packages (from scikit-learn>=0.22.2.post1->chemprop) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\noviasari\anaconda3\lib\site-packages (from scikit-learn>=0.22.2.post1->chemprop) (2.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in c:\users\noviasari\appdata\roaming\python\python311\site-packages (from sphinx>=3.1.2->chemprop) (2.17.2)
# Requirement already satisfied: docutils<0.19,>=0.14 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (0.18.1)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (2.2.0)
# Requirement already satisfied: babel>=1.3 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (0.7.12)
# Requirement already satisfied: imagesize in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in c:\users\noviasari\anaconda3\lib\site-packages (from sphinx>=3.1.2->chemprop) (2.31.0)
# Requirement already satisfied: colorama>=0.3.5 in c:\users\noviasari\appdata\roaming\python\python311\site-packages (from sphinx>=3.1.2->chemprop) (0.4.6)
# Requirement already satisfied: protobuf>=3.20 in c:\users\noviasari\anaconda3\lib\site-packages (from tensorboardX>=2.0->chemprop) (5.26.1)
# Requirement already satisfied: filelock in c:\users\noviasari\anaconda3\lib\site-packages (from torch>=1.4.0->chemprop) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\noviasari\anaconda3\lib\site-packages (from torch>=1.4.0->chemprop) (4.11.0)
# Requirement already satisfied: sympy in c:\users\noviasari\anaconda3\lib\site-packages (from torch>=1.4.0->chemprop) (1.11.1)
# Requirement already satisfied: fsspec in c:\users\noviasari\anaconda3\lib\site-packages (from torch>=1.4.0->chemprop) (2023.4.0)
# Requirement already satisfied: typing-inspect>=0.7.1 in c:\users\noviasari\anaconda3\lib\site-packages (from typed-argument-parser>=1.6.1->chemprop) (0.9.0)
# Requirement already satisfied: docstring-parser>=0.15 in c:\users\noviasari\anaconda3\lib\site-packages (from typed-argument-parser>=1.6.1->chemprop) (0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\noviasari\anaconda3\lib\site-packages (from Jinja2>=3.0->flask>=1.1.2->chemprop) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\noviasari\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=3.1.2->chemprop) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\noviasari\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=3.1.2->chemprop) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\noviasari\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=3.1.2->chemprop) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\noviasari\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=3.1.2->chemprop) (2023.7.22)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\noviasari\anaconda3\lib\site-packages (from typing-inspect>=0.7.1->typed-argument-parser>=1.6.1->chemprop) (1.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\noviasari\anaconda3\lib\site-packages (from sympy->torch>=1.4.0->chemprop) (1.3.0)
# ERROR: Invalid requirement: '#'

# %%
import chemprop
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.decomposition import PCA

# %%
def plot_parity(y_true, y_pred, y_pred_unc=None):

    axmin = min(min(y_true), min(y_pred)) - 0.1*(max(y_true)-min(y_true))
    axmax = max(max(y_true), max(y_pred)) + 0.1*(max(y_true)-min(y_true))

    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    r2 = r2_score(y_true, y_pred)

    plt.plot([axmin, axmax], [axmin, axmax], color='#00008B')

    plt.errorbar(y_true, y_pred, yerr=y_pred_unc, linewidth=0, marker='o', markeredgecolor='w', markerfacecolor='#EF7C00', alpha=1, elinewidth=1)

    plt.xlim((axmin, axmax))
    plt.ylim((axmin, axmax))

    ax = plt.gca()
    ax.set_aspect('equal')

    at = AnchoredText(
    f"MAE = {mae:.2f}\nRMSE = {rmse:.2f}\nR\u00b2 = {r2:.2f}", prop=dict(size=10), frameon=True, loc='upper left')
    at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
    ax.add_artist(at)

    plt.xlabel('Experimental IC50')
    plt.ylabel('Predicted IC50')

    plt.show()

    return

# %% [markdown]
# # Train regression model

# %%
arguments = [
    '--data_path', 'data_MW_threshold.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'test_checkpoints_reg_epoch70_MWthreshold',
    '--epochs', '70',
    '--save_smiles_splits',
    '--num_folds', '5'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python C:\Users\noviasari\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py --f=c:\Users\noviasari\AppData\Roaming\jupyter\runtime\kernel-v2-13152Vb9I65n9Q5BG.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data_MW_threshold.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 70,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 5,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_reg_epoch70_MWthreshold',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['Smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['pIC50'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 2954it [00:00, 231583.97it/s]
# 100%|██████████| 2954/2954 [00:00<00:00, 225571.65it/s]
# 100%|██████████| 2954/2954 [00:00<00:00, 119240.99it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 2954it [00:00, 326533.15it/s]
# Total size = 2,954 | train size = 2,363 | val size = 295 | test size = 296
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/70 [00:00<?, ?it/s]Epoch 0
# Loss = 9.7389e-01, PNorm = 34.0124, GNorm = 6.0183, lr_0 = 2.0532e-04
# Loss = 8.5927e-01, PNorm = 34.0209, GNorm = 8.9293, lr_0 = 3.0106e-04
# Loss = 8.8308e-01, PNorm = 34.0430, GNorm = 8.4489, lr_0 = 3.9681e-04
# Loss = 6.0930e-01, PNorm = 34.0741, GNorm = 5.1766, lr_0 = 4.9255e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.701493
#   1%|▏         | 1/70 [00:07<08:11,  7.13s/it]Epoch 1
# Loss = 6.9652e-01, PNorm = 34.1200, GNorm = 20.1654, lr_0 = 5.9787e-04
# Loss = 5.6088e-01, PNorm = 34.1561, GNorm = 7.0138, lr_0 = 6.9362e-04
# Loss = 5.5345e-01, PNorm = 34.2057, GNorm = 13.5218, lr_0 = 7.8936e-04
# Loss = 4.1920e-01, PNorm = 34.2603, GNorm = 7.0965, lr_0 = 8.8511e-04
# Loss = 4.2628e-01, PNorm = 34.3159, GNorm = 2.1133, lr_0 = 9.8085e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.131424
#   3%|▎         | 2/70 [00:15<08:38,  7.63s/it]Epoch 2
# Loss = 3.6508e-01, PNorm = 34.3733, GNorm = 8.7977, lr_0 = 9.9354e-04
# Loss = 3.4859e-01, PNorm = 34.4204, GNorm = 5.5046, lr_0 = 9.8640e-04
# Loss = 3.4753e-01, PNorm = 34.4674, GNorm = 1.6551, lr_0 = 9.7932e-04
# Loss = 4.3199e-01, PNorm = 34.5083, GNorm = 3.0168, lr_0 = 9.7229e-04
# Loss = 3.7775e-01, PNorm = 34.5582, GNorm = 5.1959, lr_0 = 9.6531e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.104685
#   4%|▍         | 3/70 [00:22<08:18,  7.45s/it]Epoch 3
# Loss = 3.4014e-01, PNorm = 34.6243, GNorm = 3.9759, lr_0 = 9.5769e-04
# Loss = 3.3842e-01, PNorm = 34.6703, GNorm = 1.9877, lr_0 = 9.5082e-04
# Loss = 3.2392e-01, PNorm = 34.7292, GNorm = 1.0421, lr_0 = 9.4399e-04
# Loss = 3.1051e-01, PNorm = 34.7716, GNorm = 2.1261, lr_0 = 9.3722e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.966728
#   6%|▌         | 4/70 [00:29<08:07,  7.38s/it]Epoch 4
# Loss = 2.8881e-01, PNorm = 34.8218, GNorm = 1.8873, lr_0 = 9.3049e-04
# Loss = 2.7409e-01, PNorm = 34.8713, GNorm = 0.7381, lr_0 = 9.2381e-04
# Loss = 2.5624e-01, PNorm = 34.9193, GNorm = 3.7720, lr_0 = 9.1718e-04
# Loss = 3.3538e-01, PNorm = 34.9779, GNorm = 6.4072, lr_0 = 9.1059e-04
# Loss = 3.4124e-01, PNorm = 35.0315, GNorm = 2.0243, lr_0 = 9.0406e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.116471
#   7%|▋         | 5/70 [00:36<07:54,  7.30s/it]Epoch 5
# Loss = 3.3256e-01, PNorm = 35.0965, GNorm = 1.2039, lr_0 = 8.9692e-04
# Loss = 2.9374e-01, PNorm = 35.1448, GNorm = 2.1592, lr_0 = 8.9048e-04
# Loss = 3.0577e-01, PNorm = 35.2001, GNorm = 4.2719, lr_0 = 8.8409e-04
# Loss = 2.8995e-01, PNorm = 35.2535, GNorm = 1.4323, lr_0 = 8.7774e-04
# Loss = 2.7886e-01, PNorm = 35.3159, GNorm = 4.7855, lr_0 = 8.7144e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.016077
#   9%|▊         | 6/70 [00:44<07:56,  7.45s/it]Epoch 6
# Loss = 2.7554e-01, PNorm = 35.3754, GNorm = 0.9198, lr_0 = 8.6456e-04
# Loss = 2.8278e-01, PNorm = 35.4339, GNorm = 2.3660, lr_0 = 8.5836e-04
# Loss = 2.6044e-01, PNorm = 35.4894, GNorm = 2.6567, lr_0 = 8.5219e-04
# Loss = 2.5204e-01, PNorm = 35.5388, GNorm = 3.5481, lr_0 = 8.4608e-04
# Loss = 2.6286e-01, PNorm = 35.5841, GNorm = 3.9666, lr_0 = 8.4000e-04
# Loss = 3.1326e-01, PNorm = 35.5888, GNorm = 3.3608, lr_0 = 8.3940e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.931174
#  10%|█         | 7/70 [00:52<07:51,  7.49s/it]Epoch 7
# Loss = 2.6625e-01, PNorm = 35.6449, GNorm = 5.8049, lr_0 = 8.3337e-04
# Loss = 3.0505e-01, PNorm = 35.7020, GNorm = 8.2631, lr_0 = 8.2739e-04
# Loss = 2.5487e-01, PNorm = 35.7593, GNorm = 2.5125, lr_0 = 8.2145e-04
# Loss = 2.2840e-01, PNorm = 35.8089, GNorm = 1.3616, lr_0 = 8.1555e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.930535
#  11%|█▏        | 8/70 [00:59<07:42,  7.46s/it]Epoch 8
# Loss = 2.3190e-01, PNorm = 35.8607, GNorm = 1.4518, lr_0 = 8.0970e-04
# Loss = 2.5849e-01, PNorm = 35.9191, GNorm = 1.2079, lr_0 = 8.0389e-04
# Loss = 2.0841e-01, PNorm = 35.9745, GNorm = 1.1115, lr_0 = 7.9811e-04
# Loss = 1.9484e-01, PNorm = 36.0169, GNorm = 1.0561, lr_0 = 7.9238e-04
# Loss = 2.1234e-01, PNorm = 36.0654, GNorm = 2.1559, lr_0 = 7.8670e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.811044
#  13%|█▎        | 9/70 [01:06<07:33,  7.44s/it]Epoch 9
# Loss = 1.8387e-01, PNorm = 36.1183, GNorm = 1.7235, lr_0 = 7.8049e-04
# Loss = 1.7996e-01, PNorm = 36.1620, GNorm = 1.6797, lr_0 = 7.7488e-04
# Loss = 1.7673e-01, PNorm = 36.2103, GNorm = 1.2411, lr_0 = 7.6932e-04
# Loss = 2.2874e-01, PNorm = 36.2608, GNorm = 0.9718, lr_0 = 7.6380e-04
# Loss = 1.8222e-01, PNorm = 36.3084, GNorm = 1.4524, lr_0 = 7.5832e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.788519
#  14%|█▍        | 10/70 [01:14<07:26,  7.44s/it]Epoch 10
# Loss = 1.8218e-01, PNorm = 36.3695, GNorm = 5.7590, lr_0 = 7.5233e-04
# Loss = 1.7924e-01, PNorm = 36.4239, GNorm = 2.2597, lr_0 = 7.4693e-04
# Loss = 1.8431e-01, PNorm = 36.4676, GNorm = 2.0259, lr_0 = 7.4157e-04
# Loss = 1.8393e-01, PNorm = 36.5090, GNorm = 3.8143, lr_0 = 7.3624e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.847331
#  16%|█▌        | 11/70 [01:21<07:21,  7.48s/it]Epoch 11
# Loss = 2.0172e-01, PNorm = 36.5535, GNorm = 5.3828, lr_0 = 7.3043e-04
# Loss = 2.0013e-01, PNorm = 36.6073, GNorm = 1.5404, lr_0 = 7.2519e-04
# Loss = 1.7786e-01, PNorm = 36.6495, GNorm = 2.9749, lr_0 = 7.1998e-04
# Loss = 2.2068e-01, PNorm = 36.6903, GNorm = 7.0927, lr_0 = 7.1481e-04
# Loss = 2.0931e-01, PNorm = 36.7536, GNorm = 1.8684, lr_0 = 7.0968e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.765131
#  17%|█▋        | 12/70 [01:29<07:12,  7.45s/it]Epoch 12
# Loss = 1.7480e-01, PNorm = 36.8061, GNorm = 2.3421, lr_0 = 7.0459e-04
# Loss = 1.6733e-01, PNorm = 36.8489, GNorm = 2.5525, lr_0 = 6.9953e-04
# Loss = 1.5207e-01, PNorm = 36.8869, GNorm = 2.0822, lr_0 = 6.9451e-04
# Loss = 1.8753e-01, PNorm = 36.9264, GNorm = 1.3126, lr_0 = 6.8952e-04
# Loss = 1.6137e-01, PNorm = 36.9769, GNorm = 2.9488, lr_0 = 6.8457e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.875020
#  19%|█▊        | 13/70 [01:36<07:02,  7.41s/it]Epoch 13
# Loss = 2.0108e-01, PNorm = 37.0173, GNorm = 0.9665, lr_0 = 6.7917e-04
# Loss = 1.7333e-01, PNorm = 37.0632, GNorm = 2.5752, lr_0 = 6.7429e-04
# Loss = 1.7091e-01, PNorm = 37.1126, GNorm = 2.9755, lr_0 = 6.6945e-04
# Loss = 1.4865e-01, PNorm = 37.1570, GNorm = 2.1309, lr_0 = 6.6465e-04
# Loss = 1.6186e-01, PNorm = 37.1828, GNorm = 1.1968, lr_0 = 6.5988e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.768784
#  20%|██        | 14/70 [01:43<06:52,  7.36s/it]Epoch 14
# Loss = 1.8519e-01, PNorm = 37.2198, GNorm = 2.9817, lr_0 = 6.5467e-04
# Loss = 1.7977e-01, PNorm = 37.2736, GNorm = 3.3203, lr_0 = 6.4997e-04
# Loss = 1.7080e-01, PNorm = 37.3116, GNorm = 2.8488, lr_0 = 6.4530e-04
# Loss = 1.5034e-01, PNorm = 37.3470, GNorm = 1.8308, lr_0 = 6.4067e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.825495
#  21%|██▏       | 15/70 [01:51<06:47,  7.41s/it]Epoch 15
# Loss = 1.3523e-01, PNorm = 37.3812, GNorm = 2.0945, lr_0 = 6.3561e-04
# Loss = 1.2814e-01, PNorm = 37.4118, GNorm = 1.1712, lr_0 = 6.3105e-04
# Loss = 1.2695e-01, PNorm = 37.4406, GNorm = 1.2990, lr_0 = 6.2652e-04
# Loss = 1.5617e-01, PNorm = 37.4771, GNorm = 0.6076, lr_0 = 6.2202e-04
# Loss = 1.6276e-01, PNorm = 37.5118, GNorm = 0.8931, lr_0 = 6.1756e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.770416
#  23%|██▎       | 16/70 [01:58<06:39,  7.39s/it]Epoch 16
# Loss = 1.3440e-01, PNorm = 37.5485, GNorm = 2.3463, lr_0 = 6.1312e-04
# Loss = 1.4533e-01, PNorm = 37.5769, GNorm = 1.7044, lr_0 = 6.0872e-04
# Loss = 1.6024e-01, PNorm = 37.6100, GNorm = 2.6441, lr_0 = 6.0435e-04
# Loss = 1.4261e-01, PNorm = 37.6502, GNorm = 2.4433, lr_0 = 6.0001e-04
# Loss = 1.3567e-01, PNorm = 37.6796, GNorm = 1.2069, lr_0 = 5.9571e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.734127
#  24%|██▍       | 17/70 [02:05<06:29,  7.35s/it]Epoch 17
# Loss = 1.2126e-01, PNorm = 37.7031, GNorm = 0.8020, lr_0 = 5.9100e-04
# Loss = 1.3367e-01, PNorm = 37.7383, GNorm = 1.3321, lr_0 = 5.8676e-04
# Loss = 1.1999e-01, PNorm = 37.7632, GNorm = 1.4104, lr_0 = 5.8255e-04
# Loss = 1.2322e-01, PNorm = 37.7840, GNorm = 0.9888, lr_0 = 5.7837e-04
# Loss = 1.4954e-01, PNorm = 37.8035, GNorm = 1.0006, lr_0 = 5.7421e-04
# Loss = 1.9878e-01, PNorm = 37.8052, GNorm = 3.3416, lr_0 = 5.7380e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.726165
#  26%|██▌       | 18/70 [02:13<06:24,  7.38s/it]Epoch 18
# Loss = 1.3082e-01, PNorm = 37.8275, GNorm = 0.9568, lr_0 = 5.6968e-04
# Loss = 1.3968e-01, PNorm = 37.8602, GNorm = 1.3537, lr_0 = 5.6559e-04
# Loss = 1.2332e-01, PNorm = 37.8813, GNorm = 1.3401, lr_0 = 5.6153e-04
# Loss = 1.1753e-01, PNorm = 37.9050, GNorm = 1.3171, lr_0 = 5.5750e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.738761
#  27%|██▋       | 19/70 [02:21<06:19,  7.44s/it]Epoch 19
# Loss = 1.7430e-01, PNorm = 37.9296, GNorm = 3.9775, lr_0 = 5.5310e-04
# Loss = 1.2372e-01, PNorm = 37.9498, GNorm = 3.0984, lr_0 = 5.4913e-04
# Loss = 1.3730e-01, PNorm = 37.9814, GNorm = 0.9964, lr_0 = 5.4519e-04
# Loss = 1.2041e-01, PNorm = 38.0047, GNorm = 1.0299, lr_0 = 5.4127e-04
# Loss = 1.4765e-01, PNorm = 38.0326, GNorm = 2.1854, lr_0 = 5.3739e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.743068
#  29%|██▊       | 20/70 [02:28<06:11,  7.43s/it]Epoch 20
# Loss = 9.9782e-02, PNorm = 38.0612, GNorm = 1.0448, lr_0 = 5.3353e-04
# Loss = 1.3076e-01, PNorm = 38.0871, GNorm = 0.7851, lr_0 = 5.2970e-04
# Loss = 1.1347e-01, PNorm = 38.1120, GNorm = 0.6276, lr_0 = 5.2590e-04
# Loss = 1.2315e-01, PNorm = 38.1290, GNorm = 0.9653, lr_0 = 5.2212e-04
# Loss = 1.2689e-01, PNorm = 38.1522, GNorm = 1.7743, lr_0 = 5.1837e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.734355
#  30%|███       | 21/70 [02:35<06:01,  7.38s/it]Epoch 21
# Loss = 1.1754e-01, PNorm = 38.1686, GNorm = 1.3405, lr_0 = 5.1428e-04
# Loss = 1.1976e-01, PNorm = 38.1899, GNorm = 2.0003, lr_0 = 5.1059e-04
# Loss = 1.0874e-01, PNorm = 38.2157, GNorm = 0.9447, lr_0 = 5.0692e-04
# Loss = 1.2511e-01, PNorm = 38.2377, GNorm = 1.8013, lr_0 = 5.0329e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.739952
#  31%|███▏      | 22/70 [02:43<05:54,  7.38s/it]Epoch 22
# Loss = 1.2871e-01, PNorm = 38.2731, GNorm = 2.1698, lr_0 = 4.9931e-04
# Loss = 1.1234e-01, PNorm = 38.2963, GNorm = 1.0127, lr_0 = 4.9573e-04
# Loss = 1.1347e-01, PNorm = 38.3185, GNorm = 1.2991, lr_0 = 4.9217e-04
# Loss = 1.2340e-01, PNorm = 38.3430, GNorm = 1.0432, lr_0 = 4.8864e-04
# Loss = 1.1665e-01, PNorm = 38.3624, GNorm = 1.1051, lr_0 = 4.8513e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.734863
#  33%|███▎      | 23/70 [02:50<05:46,  7.37s/it]Epoch 23
# Loss = 1.1381e-01, PNorm = 38.3816, GNorm = 0.4823, lr_0 = 4.8130e-04
# Loss = 1.2244e-01, PNorm = 38.4061, GNorm = 0.9712, lr_0 = 4.7784e-04
# Loss = 9.1193e-02, PNorm = 38.4275, GNorm = 0.4984, lr_0 = 4.7441e-04
# Loss = 1.1142e-01, PNorm = 38.4404, GNorm = 0.9522, lr_0 = 4.7101e-04
# Loss = 1.0353e-01, PNorm = 38.4503, GNorm = 0.6317, lr_0 = 4.6763e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.704446
#  34%|███▍      | 24/70 [02:58<05:46,  7.52s/it]Epoch 24
# Loss = 1.1718e-01, PNorm = 38.4633, GNorm = 0.8049, lr_0 = 4.6427e-04
# Loss = 9.6834e-02, PNorm = 38.4820, GNorm = 1.0281, lr_0 = 4.6094e-04
# Loss = 1.2070e-01, PNorm = 38.5017, GNorm = 2.5558, lr_0 = 4.5763e-04
# Loss = 1.0454e-01, PNorm = 38.5199, GNorm = 0.9703, lr_0 = 4.5434e-04
# Loss = 1.0513e-01, PNorm = 38.5413, GNorm = 1.3923, lr_0 = 4.5108e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.750617
#  36%|███▌      | 25/70 [03:05<05:37,  7.51s/it]Epoch 25
# Loss = 1.0778e-01, PNorm = 38.5595, GNorm = 0.9643, lr_0 = 4.4752e-04
# Loss = 1.0900e-01, PNorm = 38.5773, GNorm = 2.0916, lr_0 = 4.4431e-04
# Loss = 1.1717e-01, PNorm = 38.5980, GNorm = 0.9170, lr_0 = 4.4112e-04
# Loss = 1.2101e-01, PNorm = 38.6208, GNorm = 1.0328, lr_0 = 4.3795e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.706153
#  37%|███▋      | 26/70 [03:13<05:28,  7.46s/it]Epoch 26
# Loss = 6.7754e-02, PNorm = 38.6419, GNorm = 0.3649, lr_0 = 4.3450e-04
# Loss = 1.1760e-01, PNorm = 38.6595, GNorm = 1.9731, lr_0 = 4.3138e-04
# Loss = 1.0553e-01, PNorm = 38.6756, GNorm = 1.2452, lr_0 = 4.2828e-04
# Loss = 9.7325e-02, PNorm = 38.6915, GNorm = 0.4667, lr_0 = 4.2520e-04
# Loss = 1.0271e-01, PNorm = 38.7107, GNorm = 0.7327, lr_0 = 4.2215e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.692598
#  39%|███▊      | 27/70 [03:20<05:18,  7.41s/it]Epoch 27
# Loss = 1.4153e-01, PNorm = 38.7225, GNorm = 4.0762, lr_0 = 4.1912e-04
# Loss = 1.0501e-01, PNorm = 38.7377, GNorm = 1.1874, lr_0 = 4.1611e-04
# Loss = 1.0041e-01, PNorm = 38.7604, GNorm = 0.7966, lr_0 = 4.1313e-04
# Loss = 1.1182e-01, PNorm = 38.7725, GNorm = 2.4679, lr_0 = 4.1016e-04
# Loss = 1.1552e-01, PNorm = 38.7847, GNorm = 0.8519, lr_0 = 4.0722e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.743053
#  40%|████      | 28/70 [03:28<05:14,  7.48s/it]Epoch 28
# Loss = 1.0536e-01, PNorm = 38.8022, GNorm = 0.8219, lr_0 = 4.0400e-04
# Loss = 1.1000e-01, PNorm = 38.8229, GNorm = 0.7864, lr_0 = 4.0110e-04
# Loss = 8.7891e-02, PNorm = 38.8388, GNorm = 0.7722, lr_0 = 3.9822e-04
# Loss = 1.1085e-01, PNorm = 38.8569, GNorm = 1.3960, lr_0 = 3.9536e-04
# Loss = 9.0857e-02, PNorm = 38.8694, GNorm = 1.2268, lr_0 = 3.9253e-04
# Loss = 5.3743e-02, PNorm = 38.8704, GNorm = 1.2075, lr_0 = 3.9224e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.688925
#  41%|████▏     | 29/70 [03:35<05:06,  7.47s/it]Epoch 29
# Loss = 9.1789e-02, PNorm = 38.8795, GNorm = 1.5625, lr_0 = 3.8943e-04
# Loss = 1.0016e-01, PNorm = 38.8936, GNorm = 0.8635, lr_0 = 3.8663e-04
# Loss = 1.2215e-01, PNorm = 38.9047, GNorm = 1.7126, lr_0 = 3.8386e-04
# Loss = 8.7978e-02, PNorm = 38.9226, GNorm = 1.5406, lr_0 = 3.8110e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.731708
#  43%|████▎     | 30/70 [03:42<04:58,  7.45s/it]Epoch 30
# Loss = 9.9665e-02, PNorm = 38.9368, GNorm = 0.5542, lr_0 = 3.7809e-04
# Loss = 9.3615e-02, PNorm = 38.9491, GNorm = 0.7389, lr_0 = 3.7538e-04
# Loss = 1.0600e-01, PNorm = 38.9668, GNorm = 1.4956, lr_0 = 3.7268e-04
# Loss = 1.1557e-01, PNorm = 38.9838, GNorm = 1.4153, lr_0 = 3.7001e-04
# Loss = 1.0547e-01, PNorm = 38.9982, GNorm = 2.0222, lr_0 = 3.6735e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.692809
#  44%|████▍     | 31/70 [03:50<04:48,  7.40s/it]Epoch 31
# Loss = 1.0284e-01, PNorm = 39.0137, GNorm = 1.4953, lr_0 = 3.6471e-04
# Loss = 9.0264e-02, PNorm = 39.0262, GNorm = 0.7650, lr_0 = 3.6210e-04
# Loss = 8.6555e-02, PNorm = 39.0390, GNorm = 0.8508, lr_0 = 3.5950e-04
# Loss = 9.1393e-02, PNorm = 39.0542, GNorm = 2.2313, lr_0 = 3.5692e-04
# Loss = 9.7064e-02, PNorm = 39.0679, GNorm = 0.6931, lr_0 = 3.5435e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.713915
#  46%|████▌     | 32/70 [03:57<04:41,  7.40s/it]Epoch 32
# Loss = 8.7802e-02, PNorm = 39.0814, GNorm = 1.5956, lr_0 = 3.5156e-04
# Loss = 7.9679e-02, PNorm = 39.0935, GNorm = 0.9793, lr_0 = 3.4903e-04
# Loss = 1.0294e-01, PNorm = 39.1097, GNorm = 2.4606, lr_0 = 3.4653e-04
# Loss = 8.7844e-02, PNorm = 39.1186, GNorm = 0.8057, lr_0 = 3.4404e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.696771
#  47%|████▋     | 33/70 [04:05<04:36,  7.48s/it]Epoch 33
# Loss = 1.1040e-01, PNorm = 39.1280, GNorm = 1.7929, lr_0 = 3.4132e-04
# Loss = 8.7413e-02, PNorm = 39.1414, GNorm = 1.0262, lr_0 = 3.3887e-04
# Loss = 8.6369e-02, PNorm = 39.1521, GNorm = 0.7238, lr_0 = 3.3644e-04
# Loss = 9.5379e-02, PNorm = 39.1695, GNorm = 0.4132, lr_0 = 3.3403e-04
# Loss = 8.9470e-02, PNorm = 39.1816, GNorm = 0.6566, lr_0 = 3.3163e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.699329
#  49%|████▊     | 34/70 [04:12<04:30,  7.50s/it]Epoch 34
# Loss = 1.0887e-01, PNorm = 39.1940, GNorm = 1.2968, lr_0 = 3.2901e-04
# Loss = 9.9410e-02, PNorm = 39.2084, GNorm = 1.0109, lr_0 = 3.2665e-04
# Loss = 8.3094e-02, PNorm = 39.2196, GNorm = 1.2684, lr_0 = 3.2430e-04
# Loss = 9.6705e-02, PNorm = 39.2302, GNorm = 0.8829, lr_0 = 3.2198e-04
# Loss = 7.8190e-02, PNorm = 39.2427, GNorm = 1.9111, lr_0 = 3.1966e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.704598
#  50%|█████     | 35/70 [04:20<04:22,  7.50s/it]Epoch 35
# Loss = 8.2402e-02, PNorm = 39.2504, GNorm = 1.6326, lr_0 = 3.1737e-04
# Loss = 8.7830e-02, PNorm = 39.2608, GNorm = 0.8847, lr_0 = 3.1509e-04
# Loss = 1.0395e-01, PNorm = 39.2687, GNorm = 2.3677, lr_0 = 3.1283e-04
# Loss = 9.8968e-02, PNorm = 39.2849, GNorm = 0.9518, lr_0 = 3.1058e-04
# Loss = 8.3550e-02, PNorm = 39.2987, GNorm = 1.0492, lr_0 = 3.0835e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.708665
#  51%|█████▏    | 36/70 [04:27<04:14,  7.49s/it]Epoch 36
# Loss = 9.2111e-02, PNorm = 39.3106, GNorm = 1.1837, lr_0 = 3.0592e-04
# Loss = 8.5934e-02, PNorm = 39.3204, GNorm = 1.2692, lr_0 = 3.0372e-04
# Loss = 8.6604e-02, PNorm = 39.3300, GNorm = 0.7080, lr_0 = 3.0154e-04
# Loss = 7.7295e-02, PNorm = 39.3404, GNorm = 1.0102, lr_0 = 2.9938e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.704671
#  53%|█████▎    | 37/70 [04:35<04:10,  7.59s/it]Epoch 37
# Loss = 8.7130e-02, PNorm = 39.3519, GNorm = 0.8836, lr_0 = 2.9702e-04
# Loss = 8.5008e-02, PNorm = 39.3631, GNorm = 1.2037, lr_0 = 2.9488e-04
# Loss = 8.8970e-02, PNorm = 39.3727, GNorm = 0.7426, lr_0 = 2.9277e-04
# Loss = 9.0242e-02, PNorm = 39.3843, GNorm = 0.9786, lr_0 = 2.9066e-04
# Loss = 7.9016e-02, PNorm = 39.3940, GNorm = 1.3215, lr_0 = 2.8858e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.713648
#  54%|█████▍    | 38/70 [04:43<04:01,  7.56s/it]Epoch 38
# Loss = 7.5781e-02, PNorm = 39.4095, GNorm = 0.8802, lr_0 = 2.8630e-04
# Loss = 7.9820e-02, PNorm = 39.4194, GNorm = 1.3383, lr_0 = 2.8424e-04
# Loss = 9.2191e-02, PNorm = 39.4265, GNorm = 1.2460, lr_0 = 2.8220e-04
# Loss = 8.8270e-02, PNorm = 39.4402, GNorm = 0.5236, lr_0 = 2.8018e-04
# Loss = 8.0537e-02, PNorm = 39.4496, GNorm = 0.8249, lr_0 = 2.7817e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.695890
#  56%|█████▌    | 39/70 [04:50<03:53,  7.53s/it]Epoch 39
# Loss = 8.1732e-02, PNorm = 39.4530, GNorm = 1.4272, lr_0 = 2.7617e-04
# Loss = 8.6657e-02, PNorm = 39.4604, GNorm = 0.6036, lr_0 = 2.7419e-04
# Loss = 7.9535e-02, PNorm = 39.4710, GNorm = 1.0240, lr_0 = 2.7222e-04
# Loss = 7.9283e-02, PNorm = 39.4788, GNorm = 0.4522, lr_0 = 2.7026e-04
# Loss = 9.5970e-02, PNorm = 39.4886, GNorm = 1.1716, lr_0 = 2.6832e-04
# Loss = 8.5581e-02, PNorm = 39.4906, GNorm = 1.5721, lr_0 = 2.6813e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.732332
#  57%|█████▋    | 40/70 [04:58<03:45,  7.52s/it]Epoch 40
# Loss = 8.3248e-02, PNorm = 39.5022, GNorm = 2.6154, lr_0 = 2.6621e-04
# Loss = 7.2356e-02, PNorm = 39.5093, GNorm = 1.0739, lr_0 = 2.6430e-04
# Loss = 9.0059e-02, PNorm = 39.5198, GNorm = 0.6700, lr_0 = 2.6240e-04
# Loss = 8.2378e-02, PNorm = 39.5294, GNorm = 1.1108, lr_0 = 2.6051e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.705350
#  59%|█████▊    | 41/70 [05:05<03:40,  7.61s/it]Epoch 41
# Loss = 6.6935e-02, PNorm = 39.5359, GNorm = 0.6005, lr_0 = 2.5846e-04
# Loss = 7.2128e-02, PNorm = 39.5418, GNorm = 0.7786, lr_0 = 2.5660e-04
# Loss = 7.2069e-02, PNorm = 39.5514, GNorm = 0.7105, lr_0 = 2.5476e-04
# Loss = 9.7818e-02, PNorm = 39.5591, GNorm = 1.4026, lr_0 = 2.5293e-04
# Loss = 8.3802e-02, PNorm = 39.5679, GNorm = 0.6764, lr_0 = 2.5112e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.681073
#  60%|██████    | 42/70 [05:13<03:34,  7.66s/it]Epoch 42
# Loss = 7.4204e-02, PNorm = 39.5760, GNorm = 0.6846, lr_0 = 2.4913e-04
# Loss = 8.9051e-02, PNorm = 39.5857, GNorm = 0.7625, lr_0 = 2.4735e-04
# Loss = 8.2108e-02, PNorm = 39.5921, GNorm = 0.9661, lr_0 = 2.4557e-04
# Loss = 8.1670e-02, PNorm = 39.5987, GNorm = 2.2630, lr_0 = 2.4381e-04
# Loss = 8.8137e-02, PNorm = 39.6102, GNorm = 1.2847, lr_0 = 2.4206e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.698851
#  61%|██████▏   | 43/70 [05:21<03:24,  7.58s/it]Epoch 43
# Loss = 9.0177e-02, PNorm = 39.6213, GNorm = 0.8072, lr_0 = 2.4032e-04
# Loss = 7.0068e-02, PNorm = 39.6285, GNorm = 1.1941, lr_0 = 2.3859e-04
# Loss = 7.2842e-02, PNorm = 39.6350, GNorm = 1.4482, lr_0 = 2.3688e-04
# Loss = 7.7448e-02, PNorm = 39.6411, GNorm = 0.7178, lr_0 = 2.3518e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.687518
#  63%|██████▎   | 44/70 [05:28<03:16,  7.57s/it]Epoch 44
# Loss = 4.4008e-02, PNorm = 39.6489, GNorm = 0.8130, lr_0 = 2.3332e-04
# Loss = 8.2351e-02, PNorm = 39.6563, GNorm = 1.6947, lr_0 = 2.3165e-04
# Loss = 7.0799e-02, PNorm = 39.6645, GNorm = 0.7979, lr_0 = 2.2999e-04
# Loss = 7.4922e-02, PNorm = 39.6722, GNorm = 1.3163, lr_0 = 2.2834e-04
# Loss = 7.6361e-02, PNorm = 39.6787, GNorm = 1.7465, lr_0 = 2.2670e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.695100
#  64%|██████▍   | 45/70 [05:36<03:08,  7.54s/it]Epoch 45
# Loss = 7.4466e-02, PNorm = 39.6860, GNorm = 2.1729, lr_0 = 2.2491e-04
# Loss = 7.1480e-02, PNorm = 39.6957, GNorm = 0.4908, lr_0 = 2.2329e-04
# Loss = 7.0293e-02, PNorm = 39.7007, GNorm = 0.6379, lr_0 = 2.2169e-04
# Loss = 7.8028e-02, PNorm = 39.7078, GNorm = 0.6086, lr_0 = 2.2010e-04
# Loss = 9.1494e-02, PNorm = 39.7115, GNorm = 0.8804, lr_0 = 2.1852e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.694045
#  66%|██████▌   | 46/70 [05:43<03:01,  7.58s/it]Epoch 46
# Loss = 7.6914e-02, PNorm = 39.7226, GNorm = 1.6309, lr_0 = 2.1679e-04
# Loss = 7.6628e-02, PNorm = 39.7291, GNorm = 1.1460, lr_0 = 2.1524e-04
# Loss = 7.6059e-02, PNorm = 39.7377, GNorm = 0.4280, lr_0 = 2.1369e-04
# Loss = 6.9110e-02, PNorm = 39.7467, GNorm = 0.9619, lr_0 = 2.1216e-04
# Loss = 7.8864e-02, PNorm = 39.7543, GNorm = 0.9964, lr_0 = 2.1063e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.687079
#  67%|██████▋   | 47/70 [05:51<02:53,  7.53s/it]Epoch 47
# Loss = 8.3443e-02, PNorm = 39.7600, GNorm = 0.9698, lr_0 = 2.0912e-04
# Loss = 6.5475e-02, PNorm = 39.7667, GNorm = 0.6180, lr_0 = 2.0762e-04
# Loss = 8.0073e-02, PNorm = 39.7754, GNorm = 3.7818, lr_0 = 2.0613e-04
# Loss = 7.6029e-02, PNorm = 39.7841, GNorm = 1.3439, lr_0 = 2.0465e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.702249
#  69%|██████▊   | 48/70 [05:58<02:44,  7.48s/it]Epoch 48
# Loss = 7.6669e-02, PNorm = 39.7899, GNorm = 2.5497, lr_0 = 2.0304e-04
# Loss = 7.8331e-02, PNorm = 39.7955, GNorm = 0.8310, lr_0 = 2.0158e-04
# Loss = 7.3229e-02, PNorm = 39.8035, GNorm = 1.5306, lr_0 = 2.0013e-04
# Loss = 6.8282e-02, PNorm = 39.8097, GNorm = 1.1435, lr_0 = 1.9869e-04
# Loss = 7.1443e-02, PNorm = 39.8165, GNorm = 0.8261, lr_0 = 1.9727e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.717353
#  70%|███████   | 49/70 [06:05<02:37,  7.48s/it]Epoch 49
# Loss = 6.9370e-02, PNorm = 39.8232, GNorm = 0.6338, lr_0 = 1.9571e-04
# Loss = 7.9339e-02, PNorm = 39.8310, GNorm = 0.7668, lr_0 = 1.9431e-04
# Loss = 6.9765e-02, PNorm = 39.8372, GNorm = 1.3432, lr_0 = 1.9291e-04
# Loss = 6.4613e-02, PNorm = 39.8414, GNorm = 0.4944, lr_0 = 1.9153e-04
# Loss = 7.8841e-02, PNorm = 39.8459, GNorm = 0.5912, lr_0 = 1.9015e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0
-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.692908
#  79%|███████▊  | 55/70 [06:50<01:52,  7.48s/it]Epoch 55
# Loss = 2.8348e-02, PNorm = 39.9802, GNorm = 0.5027, lr_0 = 1.5950e-04
# Loss = 5.9791e-02, PNorm = 39.9853, GNorm = 0.8489, lr_0 = 1.5835e-04
# Loss = 7.5652e-02, PNorm = 39.9890, GNorm = 1.9322, lr_0 = 1.5722e-04
# Loss = 6.7491e-02, PNorm = 39.9922, GNorm = 0.8289, lr_0 = 1.5609e-04
# Loss = 6.7048e-02, PNorm = 39.9986, GNorm = 0.7782, lr_0 = 1.5497e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.704129
#  80%|████████  | 56/70 [06:58<01:43,  7.42s/it]Epoch 56
# Loss = 5.9971e-02, PNorm = 40.0038, GNorm = 1.0386, lr_0 = 1.5374e-04
# Loss = 6.8515e-02, PNorm = 40.0096, GNorm = 1.4534, lr_0 = 1.5264e-04
# Loss = 6.9192e-02, PNorm = 40.0143, GNorm = 0.9854, lr_0 = 1.5154e-04
# Loss = 6.6881e-02, PNorm = 40.0190, GNorm = 2.0609, lr_0 = 1.5046e-04
# Loss = 6.8599e-02, PNorm = 40.0230, GNorm = 1.0321, lr_0 = 1.4938e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.700164
#  81%|████████▏ | 57/70 [07:05<01:35,  7.38s/it]Epoch 57
# Loss = 6.2339e-02, PNorm = 40.0275, GNorm = 0.5874, lr_0 = 1.4820e-04
# Loss = 6.6045e-02, PNorm = 40.0329, GNorm = 0.5539, lr_0 = 1.4713e-04
# Loss = 6.6391e-02, PNorm = 40.0390, GNorm = 0.7653, lr_0 = 1.4608e-04
# Loss = 6.3282e-02, PNorm = 40.0420, GNorm = 0.9960, lr_0 = 1.4503e-04
# Loss = 6.9584e-02, PNorm = 40.0463, GNorm = 0.7770, lr_0 = 1.4399e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.692793
#  83%|████████▎ | 58/70 [07:12<01:28,  7.35s/it]Epoch 58
# Loss = 6.5396e-02, PNorm = 40.0509, GNorm = 0.5862, lr_0 = 1.4295e-04
# Loss = 6.3194e-02, PNorm = 40.0552, GNorm = 0.5806, lr_0 = 1.4193e-04
# Loss = 8.1569e-02, PNorm = 40.0597, GNorm = 0.8721, lr_0 = 1.4091e-04
# Loss = 6.3030e-02, PNorm = 40.0652, GNorm = 0.5687, lr_0 = 1.3990e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.681468
#  84%|████████▍ | 59/70 [07:19<01:20,  7.34s/it]Epoch 59
# Loss = 6.3747e-02, PNorm = 40.0705, GNorm = 1.0535, lr_0 = 1.3879e-04
# Loss = 6.3711e-02, PNorm = 40.0769, GNorm = 1.0851, lr_0 = 1.3780e-04
# Loss = 6.4682e-02, PNorm = 40.0799, GNorm = 1.3279, lr_0 = 1.3681e-04
# Loss = 6.2155e-02, PNorm = 40.0820, GNorm = 0.6879, lr_0 = 1.3582e-04
# Loss = 6.8140e-02, PNorm = 40.0849, GNorm = 1.2733, lr_0 = 1.3485e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.700967
#  86%|████████▌ | 60/70 [07:27<01:14,  7.45s/it]Epoch 60
# Loss = 4.8331e-02, PNorm = 40.0914, GNorm = 0.7170, lr_0 = 1.3379e-04
# Loss = 6.7073e-02, PNorm = 40.0958, GNorm = 0.6958, lr_0 = 1.3282e-04
# ...
#   warnings.warn(
# Validation rmse = 0.630083
#  71%|███████▏  | 50/70 [06:24<02:33,  7.66s/it]Epoch 50
# Loss = 7.3582e-02, PNorm = 39.3263, GNorm = 0.9775, lr_0 = 1.8879e-04
# Loss = 8.2156e-02, PNorm = 39.3309, GNorm = 0.7483, lr_0 = 1.8743e-04
# Loss = 6.7364e-02, PNorm = 39.3376, GNorm = 1.0140, lr_0 = 1.8609e-04
# Loss = 6.7668e-02, PNorm = 39.3433, GNorm = 0.7628, lr_0 = 1.8475e-04
# Loss = 7.2120e-02, PNorm = 39.3484, GNorm = 0.5789, lr_0 = 1.8342e-04
# Loss = 1.9677e-02, PNorm = 39.3489, GNorm = 1.0342, lr_0 = 1.8329e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.631879
#  73%|███████▎  | 51/70 [06:31<02:23,  7.57s/it]Epoch 51
# Loss = 7.8173e-02, PNorm = 39.3508, GNorm = 0.8159, lr_0 = 1.8198e-04
# Loss = 7.5056e-02, PNorm = 39.3546, GNorm = 0.6139, lr_0 = 1.8067e-04
# Loss = 6.1940e-02, PNorm = 39.3598, GNorm = 0.6076, lr_0 = 1.7937e-04
# Loss = 6.4908e-02, PNorm = 39.3652, GNorm = 0.6673, lr_0 = 1.7808e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.635190
#  74%|███████▍  | 52/70 [06:39<02:17,  7.65s/it]Epoch 52
# Loss = 5.4571e-02, PNorm = 39.3723, GNorm = 0.6466, lr_0 = 1.7668e-04
# Loss = 5.7111e-02, PNorm = 39.3769, GNorm = 1.1546, lr_0 = 1.7541e-04
# Loss = 6.1393e-02, PNorm = 39.3820, GNorm = 0.6611, lr_0 = 1.7415e-04
# Loss = 6.7011e-02, PNorm = 39.3857, GNorm = 1.0643, lr_0 = 1.7290e-04
# Loss = 8.7064e-02, PNorm = 39.3914, GNorm = 0.8668, lr_0 = 1.7166e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.634755
#  76%|███████▌  | 53/70 [06:47<02:09,  7.64s/it]Epoch 53
# Loss = 7.4181e-02, PNorm = 39.3944, GNorm = 1.7662, lr_0 = 1.7030e-04
# Loss = 6.7114e-02, PNorm = 39.4001, GNorm = 1.5040, lr_0 = 1.6908e-04
# Loss = 7.4733e-02, PNorm = 39.4047, GNorm = 0.9383, lr_0 = 1.6787e-04
# Loss = 7.8379e-02, PNorm = 39.4094, GNorm = 1.3226, lr_0 = 1.6666e-04
# Loss = 7.7237e-02, PNorm = 39.4167, GNorm = 0.4914, lr_0 = 1.6547e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.632697
#  77%|███████▋  | 54/70 [06:54<02:02,  7.63s/it]Epoch 54
# Loss = 5.8906e-02, PNorm = 39.4209, GNorm = 1.2094, lr_0 = 1.6428e-04
# Loss = 6.1021e-02, PNorm = 39.4237, GNorm = 0.8406, lr_0 = 1.6310e-04
# Loss = 7.6094e-02, PNorm = 39.4283, GNorm = 0.9638, lr_0 = 1.6193e-04
# Loss = 7.3297e-02, PNorm = 39.4325, GNorm = 1.7712, lr_0 = 1.6077e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.624351
#  79%|███████▊  | 55/70 [07:02<01:54,  7.64s/it]Epoch 55
# Loss = 7.2845e-02, PNorm = 39.4372, GNorm = 0.7248, lr_0 = 1.5950e-04
# Loss = 5.9852e-02, PNorm = 39.4408, GNorm = 0.5180, lr_0 = 1.5835e-04
# Loss = 6.4879e-02, PNorm = 39.4462, GNorm = 0.6814, lr_0 = 1.5722e-04
# Loss = 7.0698e-02, PNorm = 39.4508, GNorm = 0.6930, lr_0 = 1.5609e-04
# Loss = 7.6817e-02, PNorm = 39.4545, GNorm = 0.8830, lr_0 = 1.5497e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.624502
#  80%|████████  | 56/70 [07:10<01:47,  7.71s/it]Epoch 56
# Loss = 5.9178e-02, PNorm = 39.4578, GNorm = 0.6731, lr_0 = 1.5374e-04
# Loss = 7.1441e-02, PNorm = 39.4621, GNorm = 0.6623, lr_0 = 1.5264e-04
# Loss = 6.4315e-02, PNorm = 39.4668, GNorm = 0.9982, lr_0 = 1.5154e-04
# Loss = 6.6831e-02, PNorm = 39.4703, GNorm = 0.5880, lr_0 = 1.5046e-04
# Loss = 7.2940e-02, PNorm = 39.4755, GNorm = 1.1521, lr_0 = 1.4938e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.625819
#  81%|████████▏ | 57/70 [07:17<01:39,  7.64s/it]Epoch 57
# Loss = 5.9447e-02, PNorm = 39.4813, GNorm = 0.6996, lr_0 = 1.4820e-04
# Loss = 6.8545e-02, PNorm = 39.4846, GNorm = 1.7623, lr_0 = 1.4713e-04
# Loss = 6.1442e-02, PNorm = 39.4883, GNorm = 0.7310, lr_0 = 1.4608e-04
# Loss = 8.0365e-02, PNorm = 39.4923, GNorm = 0.6713, lr_0 = 1.4503e-04
# Loss = 7.0330e-02, PNorm = 39.4970, GNorm = 0.5738, lr_0 = 1.4399e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.628016
#  83%|████████▎ | 58/70 [07:25<01:32,  7.67s/it]Epoch 58
# Loss = 7.0310e-02, PNorm = 39.5015, GNorm = 0.8458, lr_0 = 1.4295e-04
# Loss = 7.0056e-02, PNorm = 39.5049, GNorm = 1.2693, lr_0 = 1.4193e-04
# Loss = 6.0404e-02, PNorm = 39.5089, GNorm = 0.5826, lr_0 = 1.4091e-04
# Loss = 7.0688e-02, PNorm = 39.5135, GNorm = 1.0393, lr_0 = 1.3990e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.623201
#  84%|████████▍ | 59/70 [07:34<01:27,  7.98s/it]Epoch 59
# Loss = 7.1593e-02, PNorm = 39.5171, GNorm = 1.0088, lr_0 = 1.3879e-04
# Loss = 5.8822e-02, PNorm = 39.5214, GNorm = 0.4910, lr_0 = 1.3780e-04
# Loss = 7.6707e-02, PNorm = 39.5252, GNorm = 1.6015, lr_0 = 1.3681e-04
# Loss = 7.3210e-02, PNorm = 39.5292, GNorm = 1.0288, lr_0 = 1.3582e-04
# Loss = 6.1750e-02, PNorm = 39.5312, GNorm = 0.9529, lr_0 = 1.3485e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.614853
#  86%|████████▌ | 60/70 [07:44<01:25,  8.57s/it]Epoch 60
# Loss = 7.1280e-02, PNorm = 39.5358, GNorm = 0.7772, lr_0 = 1.3379e-04
# Loss = 6.2070e-02, PNorm = 39.5396, GNorm = 1.3016, lr_0 = 1.3282e-04
# Loss = 5.9875e-02, PNorm = 39.5426, GNorm = 1.2421, lr_0 = 1.3187e-04
# Loss = 8.1785e-02, PNorm = 39.5456, GNorm = 0.7902, lr_0 = 1.3092e-04
# Loss = 5.4043e-02, PNorm = 39.5482, GNorm = 0.4549, lr_0 = 1.2998e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.633945
#  87%|████████▋ | 61/70 [07:53<01:19,  8.88s/it]Epoch 61
# Loss = 6.1993e-02, PNorm = 39.5526, GNorm = 1.4238, lr_0 = 1.2896e-04
# Loss = 6.5473e-02, PNorm = 39.5550, GNorm = 0.7112, lr_0 = 1.2803e-04
# Loss = 5.9241e-02, PNorm = 39.5584, GNorm = 0.7465, lr_0 = 1.2711e-04
# Loss = 7.3193e-02, PNorm = 39.5627, GNorm = 1.8298, lr_0 = 1.2620e-04
# Loss = 6.0583e-02, PNorm = 39.5673, GNorm = 1.2923, lr_0 = 1.2530e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.623035
#  89%|████████▊ | 62/70 [08:03<01:12,  9.10s/it]Epoch 62
# Loss = 6.6980e-02, PNorm = 39.5703, GNorm = 0.9793, lr_0 = 1.2440e-04
# Loss = 6.1271e-02, PNorm = 39.5730, GNorm = 0.6885, lr_0 = 1.2350e-04
# Loss = 6.6032e-02, PNorm = 39.5758, GNorm = 1.2939, lr_0 = 1.2262e-04
# Loss = 7.0164e-02, PNorm = 39.5793, GNorm = 0.6307, lr_0 = 1.2174e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.625456
#  90%|█████████ | 63/70 [08:13<01:04,  9.28s/it]Epoch 63
# Loss = 4.0502e-02, PNorm = 39.5829, GNorm = 0.4834, lr_0 = 1.2078e-04
# Loss = 7.3840e-02, PNorm = 39.5871, GNorm = 1.0719, lr_0 = 1.1991e-04
# Loss = 6.0645e-02, PNorm = 39.5890, GNorm = 0.8982, lr_0 = 1.1905e-04
# Loss = 6.3467e-02, PNorm = 39.5920, GNorm = 0.8870, lr_0 = 1.1819e-04
# Loss = 6.3852e-02, PNorm = 39.5960, GNorm = 1.1037, lr_0 = 1.1734e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.617617
#  91%|█████████▏| 64/70 [08:22<00:56,  9.39s/it]Epoch 64
# Loss = 6.0868e-02, PNorm = 39.5993, GNorm = 1.0085, lr_0 = 1.1642e-04
# Loss = 6.8364e-02, PNorm = 39.6021, GNorm = 0.6043, lr_0 = 1.1558e-04
# Loss = 5.4971e-02, PNorm = 39.6055, GNorm = 1.2996, lr_0 = 1.1475e-04
# Loss = 6.9231e-02, PNorm = 39.6091, GNorm = 0.9548, lr_0 = 1.1393e-04
# Loss = 6.6339e-02, PNorm = 39.6110, GNorm = 1.3926, lr_0 = 1.1311e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.614160
#  93%|█████████▎| 65/70 [08:32<00:47,  9.59s/it]Epoch 65
# Loss = 6.1539e-02, PNorm = 39.6137, GNorm = 0.8040, lr_0 = 1.1222e-04
# Loss = 6.3649e-02, PNorm = 39.6173, GNorm = 1.4369, lr_0 = 1.1141e-04
# Loss = 6.0534e-02, PNorm = 39.6197, GNorm = 0.9473, lr_0 = 1.1061e-04
# Loss = 7.3351e-02, PNorm = 39.6237, GNorm = 1.2813, lr_0 = 1.0982e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.616585
#  94%|█████████▍| 66/70 [08:42<00:38,  9.58s/it]Epoch 66
# Loss = 5.9419e-02, PNorm = 39.6260, GNorm = 1.0419, lr_0 = 1.0903e-04
# Loss = 5.3207e-02, PNorm = 39.6296, GNorm = 0.9988, lr_0 = 1.0825e-04
# Loss = 6.9410e-02, PNorm = 39.6329, GNorm = 0.9142, lr_0 = 1.0747e-04
# Loss = 6.2241e-02, PNorm = 39.6358, GNorm = 0.6713, lr_0 = 1.0670e-04
# Loss = 5.6490e-02, PNorm = 39.6382, GNorm = 0.7595, lr_0 = 1.0593e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.615174
#  96%|█████████▌| 67/70 [08:52<00:28,  9.61s/it]Epoch 67
# Loss = 5.7388e-02, PNorm = 39.6414, GNorm = 0.4951, lr_0 = 1.0510e-04
# Loss = 6.2992e-02, PNorm = 39.6446, GNorm = 0.9101, lr_0 = 1.0434e-04
# Loss = 6.6858e-02, PNorm = 39.6474, GNorm = 1.0595, lr_0 = 1.0359e-04
# Loss = 6.2883e-02, PNorm = 39.6505, GNorm = 0.5956, lr_0 = 1.0285e-04
# Loss = 5.7489e-02, PNorm = 39.6530, GNorm = 0.7129, lr_0 = 1.0211e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.619356
#  97%|█████████▋| 68/70 [09:01<00:19,  9.61s/it]Epoch 68
# Loss = 7.3362e-02, PNorm = 39.6558, GNorm = 0.4641, lr_0 = 1.0131e-04
# Loss = 6.1195e-02, PNorm = 39.6578, GNorm = 1.5029, lr_0 = 1.0058e-04
# Loss = 6.4300e-02, PNorm = 39.6619, GNorm = 1.7075, lr_0 = 1.0000e-04
# Loss = 5.7939e-02, PNorm = 39.6649, GNorm = 0.6745, lr_0 = 1.0000e-04
# Loss = 5.6612e-02, PNorm = 39.6668, GNorm = 1.2831, lr_0 = 1.0000e-04
# Loss = 8.7674e-02, PNorm = 39.6669, GNorm = 1.6825, lr_0 = 1.0000e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.629984
#  99%|█████████▊| 69/70 [09:11<00:09,  9.72s/it]Epoch 69
# Loss = 6.8108e-02, PNorm = 39.6699, GNorm = 0.5752, lr_0 = 1.0000e-04
# Loss = 6.3322e-02, PNorm = 39.6745, GNorm = 0.8641, lr_0 = 1.0000e-04
# Loss = 5.8991e-02, PNorm = 39.6769, GNorm = 2.2653, lr_0 = 1.0000e-04
# Loss = 5.8062e-02, PNorm = 39.6791, GNorm = 1.5819, lr_0 = 1.0000e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.623315
# 100%|██████████| 70/70 [09:21<00:00,  8.02s/it]
# Model 0 best validation rmse = 0.614160 on epoch 64
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.720102
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.720102
# 5-fold cross validation
# 	Seed 0 ==> test rmse = 0.532697
# 	Seed 1 ==> test rmse = 0.655507
# 	Seed 2 ==> test rmse = 0.639572
# 	Seed 3 ==> test rmse = 0.632940
# 	Seed 4 ==> test rmse = 0.720102
# Overall test rmse = 0.636164 +/- 0.060245
# Elapsed time = 0:44:36

# %%
mean_score, std_score
# Out:
# (0.5865254819090803, 0.05194304335163856)

# %% [markdown]
# # Predict from file

# %%
arguments = [
    '--test_path', 'test_smiles.csv',
    '--preds_path', 'test_preds_reg.csv',
    '--checkpoint_dir', 'test_checkpoints_reg',
    '--num_workers', '0',
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 296it [00:00, ?it/s]
# 100%|██████████| 296/296 [00:00<?, ?it/s]
# Validating SMILES
# Test size = 296
#   0%|          | 0/10 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  10%|█         | 1/10 [00:01<00:10,  1.13s/it]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  20%|██        | 2/10 [00:01<00:06,  1.16it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  30%|███       | 3/10 [00:02<00:05,  1.24it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  40%|████      | 4/10 [00:03<00:04,  1.36it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  50%|█████     | 5/10 [00:03<00:03,  1.41it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  60%|██████    | 6/10 [00:04<00:02,  1.44it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  70%|███████   | 7/10 [00:05<00:02,  1.35it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  80%|████████  | 8/10 [00:06<00:01,  1.38it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  90%|█████████ | 9/10 [00:06<00:00,  1.41it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# 100%|██████████| 10/10 [00:07<00:00,  1.34it/s]
# Saving predictions to test_preds_reg.csv
# Elapsed time = 0:00:08

# %%
df = pd.read_csv('test_checkpoints_reg/fold_0/test_full.csv')
df['preds'] = [x[0] for x in preds]
df.columns = ['Smiles', 'pIC50', 'preds']
df
# Out:
#                                                 Smiles     pIC50     preds
# 0    CCS(=O)(=O)C[C@H](C(C)C)N1C(=O)[C@@](C)(CC(=O)...  9.301030  9.288437
# 1    CC1OCCN(c2nc3cc(-c4noc(=O)[nH]4)nc(-c4cncc(Cl)...  9.000000  8.362511
# 2    CC(C)(C)C[C@@H]1N[C@@H](C(=O)N[C@H]2C[C@@](C)(...  7.047740  7.124038
# 3    COc1cc(C(=O)O)ccc1NC(=O)C[C@@]1(C)C[C@H](c2ccc...  9.744727  9.592572
# 4    CCOC(c1ccccn1)c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cn...  8.698970  8.414162
# ..                                                 ...       ...       ...
# 291  CC[C@H](c1nc2ccccc2s1)N1C(=O)[C@@](C)(CC(=O)O)...  7.045757  7.286000
# 292  COc1cnc(CC#N)cc1-c1nc2c(n1C(C)C)C(c1ccc(Cl)cc1...  9.443697  9.269602
# 293  CN1C2=C(C(c3ccc(Br)cc3)Oc3ccccc32)C(c2ccc(C#N)...  5.233587  5.361129
# 294  Cc1cc(Cl)ccc1C1c2c(nn(CCN3CCN(C)CC3)c2C(C)C)C(...  9.154902  8.716565
# 295  C[C@@H]1CN(C)C(=O)CN1c1nc2cc(-c3noc(=O)[nH]3)n...  7.958607  8.302238
#
# [296 rows x 3 columns]

# %%
df.to_csv('data_plot.csv')

# %%
plot_parity(df.pIC50, df.preds)
# Out:
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # Hyperparameter Tuning

# %%
# hyperopt arguments
hyperopt_args = [
    '--data_path', 'data_maxIC50_cleaned.csv',
    '--dataset_type', 'regression',
    '--num_iters', '10',
    '--config_save_path', '.',
]

# perform hyperopt
args_hyperopt = chemprop.args.HyperoptArgs().parse_args(hyperopt_args)
chemprop.hyperparameter_optimization.hyperopt(args=args_hyperopt)
# Out:
# Creating search space using parameters ['linked_hidden_size', 'depth', 'ffn_num_layers', 'dropout'].
# No manual trials loaded as part of hyperparameter search
# Initiating trial with seed 0
# Loaded 0 previous trials
# Parameters assigned with random search, 5 random trials remaining
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
# Command line
# python C:\Users\noviasari\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py --f=c:\Users\noviasari\AppData\Roaming\jupyter\runtime\kernel-v2-5424ndV1DzwMJFcx.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'config_save_path': '.',
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data_maxIC50_cleaned.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 5,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.1,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 1700,
#  'ffn_num_layers': 1,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 1700,
#  'hidden_size_solvent': 300,
#  'hyperopt_checkpoint_dir': 'C:\\Users\\NOVIAS~1\\AppData\\Local\\Temp\\tmpnifha11j',
#  'hyperopt_seed': 0,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'linked_hidden_size': 1700,
#  'log_dir': 'C:\\Users\\NOVIAS~1\\AppData\\Local\\Temp\\tmpnifha11j',
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'manual_trial_dirs': None,
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_iters': 10,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'C:\\Users\\NOVIAS~1\\AppData\\Local\\Temp\\tmpnifha11j\\trial_seed_0',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'search_parameter_keywords': ['basic'],
#  'search_parameters': ['linked_hidden_size',
#                        'depth',
#                        'ffn_num_layers',
#                        'dropout'],
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['Smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'startup_random_iters': 5,
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['pIC50'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 0it [00:00, ?it/s]
# 509it [00:00, 707.77it/s]
# 2954it [00:00, 4025.95it/s]
#   0%|          | 0/2954 [00:00<?, ?it/s]
# 100%|##########| 2954/2954 [00:00<00:00, 311556.38it/s]
#   0%|          | 0/2954 [00:00<?, ?it/s]
# 100%|##########| 2954/2954 [00:00<00:00, 98957.50it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# Total size = 2,954 | train size = 2,363 | val size = 295 | test size = 296
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=1700, bias=False)
#         (W_h): Linear(in_features=1700, out_features=1700, bias=False)
#         (W_o): Linear(in_features=1833, out_features=1700, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.1, inplace=False)
#     (1): Linear(in_features=1700, out_features=1, bias=True)
#   )
# )
# Number of parameters = 6,261,101
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 0
#   0%|          | 0/48 [00:00<?, ?it/s]
#   2%|2         | 1/48 [00:03<02:23,  3.05s/it]
#   4%|4         | 2/48 [00:05<02:02,  2.66s/it]
#   6%|6         | 3/48 [00:07<01:50,  2.45s/it]
#   8%|8         | 4/48 [00:09<01:44,  2.38s/it]
#  10%|#         | 5/48 [00:12<01:40,  2.34s/it]
#  12%|#2        | 6/48 [00:14<01:35,  2.27s/it]
#  15%|#4        | 7/48 [00:16<01:34,  2.30s/it]
#  17%|#6        | 8/48 [00:19<01:32,  2.31s/it]
#  19%|#8        | 9/48 [00:21<01:33,  2.39s/it]
# Loss = 1.3080e+00, PNorm = 61.1123, GNorm = 10.8496, lr_0 = 2.0532e-04
#  21%|##        | 10/48 [00:24<01:35,  2.52s/it]
#  23%|##2       | 11/48 [00:26<01:32,  2.51s/it]
#  25%|##5       | 12/48 [00:30<01:38,  2.73s/it]
#  27%|##7       | 13/48 [00:33<01:40,  2.86s/it]
#  29%|##9       | 14/48 [00:36<01:40,  2.96s/it]
#  31%|###1      | 15/48 [00:39<01:39,  3.02s/it]
#  33%|###3      | 16/48 [00:42<01:36,  3.03s/it]
#  35%|###5      | 17/48 [00:45<01:34,  3.05s/it]
#  38%|###7      | 18/48 [00:48<01:32,  3.10s/it]
#  40%|###9      | 19/48 [00:52<01:30,  3.13s/it]
#  62%|######2   | 30/48 [01:20<00:54,  3.03s/it]
#  65%|######4   | 31/48 [01:22<00:48,  2.83s/it]
#  67%|######6   | 32/48 [01:24<00:42,  2.67s/it]
# Loss = 1.3822e-01, PNorm = 65.7392, GNorm = 1.0066, lr_0 = 4.0542e-04
# ...
#  50%|#####     | 3/6 [00:02<00:02,  1.07it/s]
#  67%|######6   | 4/6 [00:03<00:01,  1.06it/s]
#  83%|########3 | 5/6 [00:04<00:00,  1.07it/s]
# 100%|##########| 6/6 [00:05<00:00,  1.11it/s]
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# Validation rmse = 0.816085
#  23%|##3       | 7/30 [13:04<44:01, 114.85s/it]
# Epoch 7
#   0%|          | 0/48 [00:00<?, ?it/s]
#   2%|2         | 1/48 [00:02<02:12,  2.83s/it]
#   4%|4         | 2/48 [00:05<02:08,  2.79s/it]
#   6%|6         | 3/48 [00:08<02:06,  2.81s/it]
#   8%|8         | 4/48 [00:11<02:03,  2.81s/it]
#  10%|#         | 5/48 [00:14<02:02,  2.84s/it]
#  12%|#2        | 6/48 [00:17<02:00,  2.86s/it]
#  15%|#4        | 7/48 [00:19<01:49,  2.66s/it]
#  17%|#6        | 8/48 [00:21<01:40,  2.51s/it]
#  23%|##3       | 7/30 [13:26<44:09, 115.18s/it]
#  67%|██████▋   | 2/3 [13:27<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       9 # perform hyperopt
#      10 args_hyperopt = chemprop.args.HyperoptArgs().parse_args(hyperopt_args)
# ---> 11 chemprop.hyperparameter_optimization.hyperopt(args=args_hyperopt)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\utils.py:591, in timeit.<locals>.timeit_decorator.<locals>.wrap(*args, **kwargs)
#     588 @wraps(func)
#     589 def wrap(*args, **kwargs) -> Any:
#     590     start_time = time()
# --> 591     result = func(*args, **kwargs)
#     592     delta = timedelta(seconds=round(time() - start_time))
#     593     info = logging.getLogger(logger_name).info if logger_name is not None else print
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\hyperparameter_optimization.py:166, in hyperopt(args)
#     163 else:
#     164     logger.info(f"Parameters assigned with TPE directed search")
# --> 166 fmin(
#     167     fmin_objective,
#     168     space,
#     169     algo=partial(tpe.suggest, n_startup_jobs=args.startup_random_iters),
#     170     max_evals=len(trials) + 1,
#     171     trials=trials,
#     172 )
#     174 # Create a trials object with only the last instance by merging the last data with an empty trials object
#     175 last_trial = merge_trials(Trials(), [trials.trials[-1]])
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\hyperparameter_optimization.py:100, in hyperopt.<locals>.objective(hyperparams, seed)
#      97     hyper_args.final_lr = hyperparams["max_lr"] * hyperparams["final_lr_ratio"]
#      99 # Cross validate
# --> 100 mean_score, std_score = cross_validate(args=hyper_args, train_func=run_training)
#     102 # Record results
#     103 temp_model = MoleculeModel(hyper_args)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\utils.py:591, in timeit.<locals>.timeit_decorator.<locals>.wrap(*args, **kwargs)
#     588 @wraps(func)
#     589 def wrap(*args, **kwargs) -> Any:
#     590     start_time = time()
# --> 591     result = func(*args, **kwargs)
#     592     delta = timedelta(seconds=round(time() - start_time))
#     593     info = logging.getLogger(logger_name).info if logger_name is not None else print
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\train\cross_validate.py:119, in cross_validate(args, train_func)
#     116         model_scores = json.load(f)
#     117 # Otherwise, train the models
#     118 else:
# --> 119     model_scores = train_func(args, data, logger)
#     121 for metric, scores in model_scores.items():
#     122     all_scores[metric].append(scores)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\train\run_training.py:295, in run_training(args, data, logger)
#     293 for epoch in trange(args.epochs):
#     294     debug(f'Epoch {epoch}')
# --> 295     n_iter = train(
#     296         model=model,
#     297         data_loader=train_data_loader,
#     298         loss_func=loss_func,
#     299         optimizer=optimizer,
#     300         scheduler=scheduler,
#     301         args=args,
#     302         n_iter=n_iter,
#     303         atom_bond_scaler=atom_bond_scaler,
#     304         logger=logger,
#     305         writer=writer
#     306     )
#     307     if isinstance(scheduler, ExponentialLR):
#     308         scheduler.step()
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\train\train.py:128, in train(model, data_loader, loss_func, optimizer, scheduler, args, n_iter, atom_bond_scaler, logger, writer)
#     126 # Run model
#     127 model.zero_grad()
# --> 128 preds = model(
#     129     mol_batch,
#     130     features_batch,
#     131     atom_descriptors_batch,
#     132     atom_features_batch,
#     133     bond_descriptors_batch,
#     134     bond_features_batch,
#     135     constraints_batch,
#     136     bond_types_batch,
#     137 )
#     139 # Move tensors to correct device
#     140 torch_device = args.device
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\models\model.py:278, in MoleculeModel.forward(self, batch, features_batch, atom_descriptors_batch, atom_features_batch, bond_descriptors_batch, bond_features_batch, constraints_batch, bond_types_batch)
#     276     output = self.readout(encodings, constraints_batch, bond_types_batch)
#     277 else:
# --> 278     encodings = self.encoder(
#     279         batch,
#     280         features_batch,
#     281         atom_descriptors_batch,
#     282         atom_features_batch,
#     283         bond_descriptors_batch,
#     284         bond_features_batch,
#     285     )
#     286     output = self.readout(encodings)
#     288 # Don't apply sigmoid during training when using BCEWithLogitsLoss
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\models\mpn.py:319, in MPN.forward(self, batch, features_batch, atom_descriptors_batch, atom_features_batch, bond_descriptors_batch, bond_features_batch)
#     317 else:
#     318     if not self.reaction_solvent:
# --> 319         encodings = [enc(ba) for enc, ba in zip(self.encoder, batch)]
#     320     else:
#     321         encodings = []
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\models\mpn.py:319, in <listcomp>(.0)
#     317 else:
#     318     if not self.reaction_solvent:
# --> 319         encodings = [enc(ba) for enc, ba in zip(self.encoder, batch)]
#     320     else:
#     321         encodings = []
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\chemprop\models\mpn.py:137, in MPNEncoder.forward(self, mol_graph, atom_descriptors_batch, bond_descriptors_batch)
#     134     rev_message = message[b2revb]  # num_bonds x hidden
#     135     message = a_message[b2a] - rev_message  # num_bonds x hidden
# --> 137 message = self.W_h(message)
#     138 message = self.act_func(input + message)  # num_bonds x hidden_size
#     139 message = self.dropout(message)  # num_bonds x hidden
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# # Predict from SMILES list

# %%
smiles = [['CCC'], ['CCCC'], ['OCC']]
arguments = [
    '--test_path', '/dev/null',
    '--preds_path', '/dev/null',
    '--checkpoint_dir', 'test_checkpoints_reg'
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args, smiles=smiles)
# Out:
# Loading training args
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 3
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.07it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.42it/s]
# Saving predictions to /dev/null
# Elapsed time = 0:00:01

# %% [markdown]
# # Load model once, predict multiple times

# %%
arguments = [
    '--test_path', '/dev/null',
    '--preds_path', '/dev/null',
    '--checkpoint_dir', 'test_checkpoints_reg'
]

args = chemprop.args.PredictArgs().parse_args(arguments)

model_objects = chemprop.train.load_model(args=args)

smiles = [['CCC'], ['CCCC'], ['OCC']]
preds = chemprop.train.make_predictions(args=args, smiles=smiles, model_objects=model_objects)

smiles = [['CCCC'], ['CCCCC'], ['COCC']]
preds = chemprop.train.make_predictions(args=args, smiles=smiles, model_objects=model_objects)
# Out:
# Loading training args
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 3
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# Saving predictions to /dev/null
# Elapsed time = 0:00:00
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 3
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.66it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
# Saving predictions to /dev/null
# Elapsed time = 0:00:00

# %% [markdown]
# # Reactions

# %%
reaction_reg_df = pd.read_csv('data/reaction_regression.csv')
reaction_reg_df
# Out:
#                                                    AAM         ea
# 0    [O:1]([C:2]([C:3]([C:4](=[O:5])[C:6]([O:7][H:1...   8.898934
# 1    [C:1]1([H:8])([H:9])[O:2][C@@:3]2([H:10])[C@@:...   5.464328
# 2    [C:1]([C@@:2]1([H:11])[C@@:3]2([H:12])[C:4]([H...   5.270552
# 3    [C:1]([O:2][C:3]([C@@:4]([C:5]([H:14])([H:15])...   8.473006
# 4    [C:1]([C:2]#[C:3][C:4]([C:5](=[O:6])[H:12])([H...   5.579037
# ..                                                 ...        ...
# 495  [C:1]([c:2]1[c:3]([H:10])[n:4]([H:11])[n:5][c:...  14.662005
# 496  [C:1]([C@@:2]1([H:11])[N:3]([H:12])[C@:4]1([C:...   5.146017
# 497  [C:1]([C@@:2]1([H:10])[C:3]([H:11])([H:12])[C:...   8.362688
# 498  [C:1]([c:2]1[c:3]([H:11])[o:4][c:5]([O:6][H:12...  12.416359
# 499  [N:1]([c:2]1[c:3]([O:4][H:10])[n:5]([H:11])[c:...   7.785556
#
# [500 rows x 2 columns]

# %%
arguments = [
    '--data_path', 'data/reaction_regression.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'test_checkpoints_reaction',
    '--epochs', '5',
    '--reaction',
    '--save_smiles_splits'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-8f687a13-fd1d-4bb6-bf15-8368444c40f1.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/reaction_regression.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 5,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': True,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_reaction',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['AAM'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['ea'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Setting molecule featurization parameters to default.
# Loading data
# 500it [00:00, 47996.34it/s]
# 100%|██████████| 500/500 [00:00<00:00, 127968.76it/s]
# 100%|██████████| 500/500 [00:00<00:00, 7069.00it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 500it [00:00, 63780.06it/s]
# Total size = 500 | train size = 400 | val size = 50 | test size = 50
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=193, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=465, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 378,601
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:00,  7.57it/s]
#  25%|██▌       | 2/8 [00:00<00:00,  7.45it/s]
#  38%|███▊      | 3/8 [00:00<00:00,  7.91it/s]
#  50%|█████     | 4/8 [00:00<00:00,  7.87it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  8.06it/s]
#  75%|███████▌  | 6/8 [00:00<00:00,  8.04it/s]
#  88%|████████▊ | 7/8 [00:00<00:00,  8.07it/s]
# 100%|██████████| 8/8 [00:01<00:00,  8.12it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.271719
#  20%|██        | 1/5 [00:01<00:05,  1.33s/it]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 7.7459e-01, PNorm = 34.6705, GNorm = 6.2133, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00, 10.25it/s]
#  50%|█████     | 4/8 [00:00<00:00,  9.73it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  9.57it/s]
#  75%|███████▌  | 6/8 [00:00<00:00,  8.95it/s]
# 100%|██████████| 8/8 [00:00<00:00,  9.80it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.165562
#  40%|████      | 2/5 [00:02<00:03,  1.23s/it]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 12.25it/s]Loss = 8.0665e-01, PNorm = 34.7094, GNorm = 10.4500, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00, 11.38it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 10.69it/s]
# 100%|██████████| 8/8 [00:00<00:00, 10.33it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.293178
#  60%|██████    | 3/5 [00:03<00:02,  1.09s/it]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:01,  6.24it/s]
#  25%|██▌       | 2/8 [00:00<00:00,  6.36it/s]
#  38%|███▊      | 3/8 [00:00<00:00,  6.23it/s]
#  50%|█████     | 4/8 [00:00<00:00,  6.40it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  6.83it/s]Loss = 7.1648e-01, PNorm = 34.7282, GNorm = 2.6230, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00,  5.82it/s]
#  88%|████████▊ | 7/8 [00:01<00:00,  5.71it/s]
# 100%|██████████| 8/8 [00:01<00:00,  5.45it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.60it/s]
#                                              Validation rmse = 2.401798
#  80%|████████  | 4/5 [00:04<00:01,  1.28s/it]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:01,  4.01it/s]
#  25%|██▌       | 2/8 [00:00<00:01,  3.85it/s]
#  38%|███▊      | 3/8 [00:00<00:01,  3.94it/s]
#  50%|█████     | 4/8 [00:01<00:01,  3.89it/s]
#  62%|██████▎   | 5/8 [00:01<00:00,  4.14it/s]
#  75%|███████▌  | 6/8 [00:01<00:00,  4.27it/s]
#  88%|████████▊ | 7/8 [00:01<00:00,  5.10it/s]Loss = 6.5946e-01, PNorm = 34.7339, GNorm = 4.1201, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:01<00:00,  5.93it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.034656
# 100%|██████████| 5/5 [00:06<00:00,  1.40s/it]
# Model 0 best validation rmse = 2.034656 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 0 test rmse = 1.969818
# Ensemble test rmse = 1.969818
# 1-fold cross validation
# 	Seed 0 ==> test rmse = 1.969818
# Overall test rmse = 1.969818 +/- 0.000000
# Elapsed time = 0:00:08

# %%
arguments = [
    '--test_path', 'test_checkpoints_reaction/fold_0/test_smiles.csv',
    '--preds_path', 'test_preds_reaction.csv',
    '--checkpoint_dir', 'test_checkpoints_reaction'
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 50it [00:00, 72666.39it/s]
# 100%|██████████| 50/50 [00:00<00:00, 73558.47it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating SMILES
# Test size = 50
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# Saving predictions to test_preds_reaction.csv
# Elapsed time = 0:00:01

# %%
df = pd.read_csv('test_checkpoints_reaction/fold_0/test_full.csv')
df['preds'] = [x[0] for x in preds]

plot_parity(df.ea, df.preds)

# %% [markdown]
# # Multiple-Molecule Inputs

# %%
multimolecule_df = pd.read_csv('data/classification_multimolecule.csv')
multimolecule_df
# Out:
#                                           mol a smiles  \
# 0    CC(C)CC1C(=O)NC(C(=O)NC(C(=O)NC(C(=O)NCCC(C(=O...
# 1    CCC(C)CCCC(=O)NC(CCN)C(=O)NC(C(C)O)C(=O)NC(CCN...
# 2    CCC(C)CCCC(=O)NC(CCN)C(=O)NC(C(C)O)C(=O)NC(CCN...
# 3    CCC(C)CCCC(=O)NC(CCN)C(=O)NC(C(C)O)C(=O)NC(CCN...
# 4    C[C@H]([C@H]1C(=O)NCC[C@@H](C(=O)N[C@H](C(=O)N...
# ..                                                 ...
# 254  CC(C)CC1C(=O)NC(C(=O)N2CCCC2C(=O)NC(C(=O)NC(C(...
# 255  CCC(C)CCCC(=O)NC(CCN)C(=O)NC(C(C)O)C(=O)NC(CCN...
# 256  CC(C)CC1C(=O)NC(C(=O)NC(C(=O)NC(C(=O)NCCC(C(=O...
# 257                              CCOP(=O)(O)OP(=O)(O)O
# 258  CCC(C)CCCC(=O)NC(CCN)C(=O)NC(C(C)O)C(=O)NC(CCN...
#
#                                           mol b Smiles  synergy
# 0    CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...        1
# 1    CC(C1CCC(C(O1)OC2C(CC(C(C2O)OC3C(C(C(CO3)(C)O)...        0
# 2    CC(C)(C(=O)O)ON=C(C1=CSC(=N1)N)C(=O)NC2C3N(C2=...        0
# 3    CC(C)(C)NCC(=O)NC1=CC(=C2CC3CC4C(C(=O)C(=C(C4(...        1
# 4    CN1C(=NC(=O)C(=O)N1)SCC2=C(N3C(C(C3=O)NC(=O)C(...        1
# ..                                                 ...      ...
# 254                           [N+](=O)([O-])[O-].[Ag+]        0
# 255                                C1=CC=C2C(=C1)C=CN2        1
# 256  CC1C2C(C(=O)N2C(=C1SC3CC(NC3)C(=O)N(C)C)C(=O)O...        1
# 257    C1=CC(=CC=C1C(C(CO)NC(=O)C(Cl)Cl)O)[N+](=O)[O-]        1
# 258  C1C(C(C(C(C1N)OC2C(C(C(C(O2)CN)O)O)O)O)OC3C(C(...        1
#
# [259 rows x 3 columns]

# %%
arguments = [
    '--data_path', 'data/classification_multimolecule.csv',
    '--dataset_type', 'classification',
    '--save_dir', 'test_checkpoints_multimolecule',
    '--epochs', '5',
    '--save_smiles_splits',
    '--number_of_molecules', '2',
    '--split_key_molecule', '1' # defaults to 0 (1st column) if not specified
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-8f687a13-fd1d-4bb6-bf15-8368444c40f1.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/classification_multimolecule.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 5,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 2,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_multimolecule',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['mol a smiles', 'mol b Smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 1,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['synergy'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Setting molecule featurization parameters to default.
# Loading data
# 259it [00:00, 27657.33it/s]
# 100%|██████████| 259/259 [00:00<00:00, 71313.91it/s]
# 100%|██████████| 259/259 [00:00<00:00, 2577.63it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# Class sizes
# synergy 0: 40.93%, 1: 59.07%
# 0it [00:00, ?it/s]Warning: Repeated SMILES found in data, pickle file of split indices cannot distinguish entries and will not be generated.
# 15it [00:00, 3696.94it/s]
# Total size = 259 | train size = 207 | val size = 26 | test size = 26
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#       (1): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=600, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 709,801
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:01<00:06,  1.71s/it]
#  40%|████      | 2/5 [00:02<00:04,  1.39s/it]
#  60%|██████    | 3/5 [00:04<00:02,  1.29s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.35s/it]
# 100%|██████████| 5/5 [00:05<00:00,  1.06it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.99it/s]
#                                              Validation auc = 0.606250
#  20%|██        | 1/5 [00:06<00:25,  6.42s/it]Epoch 1
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.12s/it]
#  40%|████      | 2/5 [00:03<00:05,  1.91s/it]
#  60%|██████    | 3/5 [00:05<00:03,  1.57s/it]
#  80%|████████  | 4/5 [00:06<00:01,  1.62s/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.08s/it]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.13it/s]
#                                              Validation auc = 0.525000
#  40%|████      | 2/5 [00:13<00:20,  6.79s/it]Epoch 2
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.74it/s]Loss = 6.6435e-01, PNorm = 45.8623, GNorm = 1.1497, lr_0 = 3.8312e-04
#
#  40%|████      | 2/5 [00:01<00:01,  1.64it/s]
#  60%|██████    | 3/5 [00:01<00:01,  1.60it/s]
#  80%|████████  | 4/5 [00:02<00:00,  1.63it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.75it/s]
#                                              Validation auc = 0.525000
#  60%|██████    | 3/5 [00:16<00:09,  4.94s/it]Epoch 3
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.63it/s]
#  40%|████      | 2/5 [00:01<00:01,  1.61it/s]
#  60%|██████    | 3/5 [00:01<00:01,  1.63it/s]
#  80%|████████  | 4/5 [00:02<00:00,  1.65it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.35it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.66it/s]
#                                              Validation auc = 0.543750
#  80%|████████  | 4/5 [00:18<00:04,  4.07s/it]Epoch 4
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.65it/s]
#  40%|████      | 2/5 [00:01<00:02,  1.44it/s]
#  60%|██████    | 3/5 [00:02<00:01,  1.27it/s]Loss = 6.1639e-01, PNorm = 45.8728, GNorm = 0.7998, lr_0 = 1.0000e-04
#
#  80%|████████  | 4/5 [00:03<00:00,  1.17it/s]Loss = 5.9861e-01, PNorm = 45.8732, GNorm = 1.6586, lr_0 = 1.0000e-04
#
# 100%|██████████| 5/5 [00:03<00:00,  1.66it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.75it/s]
#                                              Validation auc = 0.543750
# 100%|██████████| 5/5 [00:22<00:00,  4.52s/it]
# Model 0 best validation auc = 0.606250 on epoch 0
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "encoder.encoder.1.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.1.W_i.weight".
# Loading pretrained parameter "encoder.encoder.1.W_h.weight".
# Loading pretrained parameter "encoder.encoder.1.W_o.weight".
# Loading pretrained parameter "encoder.encoder.1.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 0 test auc = 0.709091
# Ensemble test auc = 0.709091
# 1-fold cross validation
# 	Seed 0 ==> test auc = 0.709091
# Overall test auc = 0.709091 +/- 0.000000
# Elapsed time = 0:00:24

# %%
arguments = [
    '--test_path', 'test_checkpoints_multimolecule/fold_0/test_smiles.csv',
    '--preds_path', 'test_preds_multimolecule.csv',
    '--checkpoint_dir', 'test_checkpoints_multimolecule',
    '--number_of_molecules', '2',
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 26it [00:00, 60282.98it/s]
# 100%|██████████| 26/26 [00:00<00:00, 65183.45it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating SMILES
# Test size = 26
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "encoder.encoder.1.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.1.W_i.weight".
# Loading pretrained parameter "encoder.encoder.1.W_h.weight".
# Loading pretrained parameter "encoder.encoder.1.W_o.weight".
# Loading pretrained parameter "encoder.encoder.1.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]
# Saving predictions to test_preds_multimolecule.csv
# Elapsed time = 0:00:01

# %% [markdown]
# # Split Type

# %%
arguments = [
    '--data_path', 'data_maxIC50_cleaned.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'test_checkpoints_splits',
    '--epochs', '70',
    '--split_type', 'scaffold_balanced',
    '--save_smiles_splits',
    '--num_folds', '10'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python C:\Users\noviasari\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py --f=c:\Users\noviasari\AppData\Roaming\jupyter\runtime\kernel-v2-5424ndV1DzwMJFcx.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data_maxIC50_cleaned.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 70,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 10,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_splits',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['Smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'scaffold_balanced',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['pIC50'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 2954it [00:00, 268332.27it/s]
# 100%|██████████| 2954/2954 [00:00<00:00, 311258.96it/s]
# 100%|██████████| 2954/2954 [00:01<00:00, 2920.88it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 100%|██████████| 2954/2954 [00:00<00:00, 3798.06it/s]
# Total scaffolds = 834 | train scaffolds = 672 | val scaffolds = 105 | test scaffolds = 57
# Label averages per scaffold, in decreasing order of scaffold frequency,capped at 10 scaffolds and 20 labels:
# Scaffold 0
# Task 0: count = 142 | target average = 8.042335
#
#
# Scaffold 1
# Task 0: count = 76 | target average = 9.247853
#
#
# Scaffold 2
# Task 0: count = 67 | target average = 8.263976
#
#
# Scaffold 3
# Task 0: count = 64 | target average = 9.592412
#
#
# Scaffold 4
# Task 0: count = 63 | target average = 5.467494
#
#
# Scaffold 5
# Task 0: count = 56 | target average = 4.976190
#
#
# Scaffold 6
# Task 0: count = 47 | target average = 9.229614
#
#
# Scaffold 7
# Task 0: count = 45 | target average = 5.765372
#
#
# Scaffold 8
# Task 0: count = 42 | target average = 9.171748
#
#
# Scaffold 9
# Task 0: count = 42 | target average = 8.619772
#
#
# 2954it [00:00, 392075.38it/s]
# Total size = 2,954 | train size = 2,363 | val size = 295 | test size = 296
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/70 [00:00<?, ?it/s]Epoch 0
# Loss = 9.4192e-01, PNorm = 34.0123, GNorm = 2.4803, lr_0 = 2.0532e-04
# Loss = 8.5749e-01, PNorm = 34.0227, GNorm = 6.5531, lr_0 = 3.0106e-04
# Loss = 8.1609e-01, PNorm = 34.0435, GNorm = 6.4815, lr_0 = 3.9681e-04
# Loss = 6.3672e-01, PNorm = 34.0721, GNorm = 1.5072, lr_0 = 4.9255e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.193882
#   1%|▏         | 1/70 [00:11<13:05, 11.38s/it]Epoch 1
# Loss = 7.4423e-01, PNorm = 34.1070, GNorm = 14.1179, lr_0 = 5.9787e-04
# Loss = 5.7317e-01, PNorm = 34.1465, GNorm = 2.1209, lr_0 = 6.9362e-04
# Loss = 4.3889e-01, PNorm = 34.2053, GNorm = 10.1345, lr_0 = 7.8936e-04
# Loss = 4.6146e-01, PNorm = 34.2683, GNorm = 2.3840, lr_0 = 8.8511e-04
# Loss = 4.2158e-01, PNorm = 34.3281, GNorm = 4.7627, lr_0 = 9.8085e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.070935
#   3%|▎         | 2/70 [00:18<10:09,  8.97s/it]Epoch 2
# Loss = 3.6554e-01, PNorm = 34.3930, GNorm = 2.3712, lr_0 = 9.9354e-04
# Loss = 3.7066e-01, PNorm = 34.4482, GNorm = 4.7158, lr_0 = 9.8640e-04
# Loss = 3.8107e-01, PNorm = 34.4908, GNorm = 2.8055, lr_0 = 9.7932e-04
# Loss = 3.2951e-01, PNorm = 34.5357, GNorm = 3.3824, lr_0 = 9.7229e-04
# Loss = 3.5023e-01, PNorm = 34.5866, GNorm = 1.3766, lr_0 = 9.6531e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.161872
#   4%|▍         | 3/70 [00:25<09:05,  8.14s/it]Epoch 3
# Loss = 3.6932e-01, PNorm = 34.6536, GNorm = 5.2188, lr_0 = 9.5769e-04
# Loss = 3.3392e-01, PNorm = 34.7046, GNorm = 2.5461, lr_0 = 9.5082e-04
# Loss = 3.5523e-01, PNorm = 34.7464, GNorm = 7.2115, lr_0 = 9.4399e-04
# Loss = 3.6017e-01, PNorm = 34.8031, GNorm = 2.6738, lr_0 = 9.3722e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.989189
#   6%|▌         | 4/70 [00:32<08:22,  7.61s/it]Epoch 4
# Loss = 3.0041e-01, PNorm = 34.8669, GNorm = 3.5865, lr_0 = 9.3049e-04
# Loss = 2.9454e-01, PNorm = 34.9184, GNorm = 1.6405, lr_0 = 9.2381e-04
# Loss = 2.5234e-01, PNorm = 34.9630, GNorm = 2.1269, lr_0 = 9.1718e-04
# Loss = 3.0225e-01, PNorm = 35.0078, GNorm = 0.8915, lr_0 = 9.1059e-04
# Loss = 2.5908e-01, PNorm = 35.0565, GNorm = 2.9271, lr_0 = 9.0406e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.058424
#   7%|▋         | 5/70 [00:40<08:10,  7.55s/it]Epoch 5
# Loss = 2.6035e-01, PNorm = 35.1087, GNorm = 4.2221, lr_0 = 8.9692e-04
# Loss = 2.5010e-01, PNorm = 35.1571, GNorm = 1.5478, lr_0 = 8.9048e-04
# Loss = 2.5951e-01, PNorm = 35.2103, GNorm = 1.2185, lr_0 = 8.8409e-04
# Loss = 2.6718e-01, PNorm = 35.2708, GNorm = 4.6018, lr_0 = 8.7774e-04
# Loss = 2.4202e-01, PNorm = 35.3214, GNorm = 0.3516, lr_0 = 8.7144e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.945057
#   9%|▊         | 6/70 [00:47<07:57,  7.46s/it]Epoch 6
# Loss = 2.9814e-01, PNorm = 35.3824, GNorm = 5.9773, lr_0 = 8.6456e-04
# Loss = 2.3118e-01, PNorm = 35.4410, GNorm = 4.1074, lr_0 = 8.5836e-04
# Loss = 2.2315e-01, PNorm = 35.4995, GNorm = 1.0345, lr_0 = 8.5219e-04
# Loss = 2.2977e-01, PNorm = 35.5522, GNorm = 2.3602, lr_0 = 8.4608e-04
# Loss = 1.9935e-01, PNorm = 35.6071, GNorm = 2.4183, lr_0 = 8.4000e-04
# Loss = 2.4735e-01, PNorm = 35.6138, GNorm = 6.9647, lr_0 = 8.3940e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.922701
#  10%|█         | 7/70 [00:54<07:42,  7.35s/it]Epoch 7
# Loss = 2.3060e-01, PNorm = 35.6717, GNorm = 0.6818, lr_0 = 8.3337e-04
# Loss = 2.6700e-01, PNorm = 35.7264, GNorm = 8.3002, lr_0 = 8.2739e-04
# Loss = 2.1543e-01, PNorm = 35.7896, GNorm = 2.7837, lr_0 = 8.2145e-04
# Loss = 2.3839e-01, PNorm = 35.8510, GNorm = 4.0897, lr_0 = 8.1555e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.902402
#  11%|█▏        | 8/70 [01:01<07:32,  7.30s/it]Epoch 8
# Loss = 1.6540e-01, PNorm = 35.9005, GNorm = 2.4005, lr_0 = 8.0970e-04
# Loss = 2.2808e-01, PNorm = 35.9482, GNorm = 1.1192, lr_0 = 8.0389e-04
# Loss = 1.9342e-01, PNorm = 35.9925, GNorm = 1.0382, lr_0 = 7.9811e-04
# Loss = 1.9617e-01, PNorm = 36.0306, GNorm = 1.2788, lr_0 = 7.9238e-04
# Loss = 1.7050e-01, PNorm = 36.0745, GNorm = 1.9470, lr_0 = 7.8670e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.900745
#  13%|█▎        | 9/70 [01:09<07:30,  7.38s/it]Epoch 9
# Loss = 1.9092e-01, PNorm = 36.1373, GNorm = 0.9869, lr_0 = 7.8049e-04
# Loss = 1.7268e-01, PNorm = 36.1812, GNorm = 1.4213, lr_0 = 7.7488e-04
# Loss = 1.8902e-01, PNorm = 36.2277, GNorm = 2.2309, lr_0 = 7.6932e-04
# Loss = 2.0822e-01, PNorm = 36.2654, GNorm = 1.5478, lr_0 = 7.6380e-04
# Loss = 1.8250e-01, PNorm = 36.3114, GNorm = 2.7681, lr_0 = 7.5832e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.876451
#  14%|█▍        | 10/70 [01:16<07:21,  7.36s/it]Epoch 10
# Loss = 1.8893e-01, PNorm = 36.3720, GNorm = 1.2477, lr_0 = 7.5233e-04
# Loss = 1.7730e-01, PNorm = 36.4256, GNorm = 1.0594, lr_0 = 7.4693e-04
# Loss = 2.0579e-01, PNorm = 36.4749, GNorm = 3.1353, lr_0 = 7.4157e-04
# Loss = 1.8076e-01, PNorm = 36.5071, GNorm = 2.0041, lr_0 = 7.3624e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.860508
#  16%|█▌        | 11/70 [01:23<07:12,  7.33s/it]Epoch 11
# Loss = 1.6879e-01, PNorm = 36.5585, GNorm = 0.8874, lr_0 = 7.3043e-04
# Loss = 1.7090e-01, PNorm = 36.6030, GNorm = 0.8041, lr_0 = 7.2519e-04
# Loss = 1.6301e-01, PNorm = 36.6387, GNorm = 1.4236, lr_0 = 7.1998e-04
# Loss = 1.5242e-01, PNorm = 36.6726, GNorm = 0.8554, lr_0 = 7.1481e-04
# Loss = 1.3733e-01, PNorm = 36.7056, GNorm = 0.6504, lr_0 = 7.0968e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.888439
#  17%|█▋        | 12/70 [01:31<07:09,  7.40s/it]Epoch 12
# Loss = 1.4780e-01, PNorm = 36.7412, GNorm = 1.3806, lr_0 = 7.0459e-04
# Loss = 1.6228e-01, PNorm = 36.7769, GNorm = 1.8174, lr_0 = 6.9953e-04
# Loss = 1.5582e-01, PNorm = 36.8182, GNorm = 1.6072, lr_0 = 6.9451e-04
# Loss = 1.6305e-01, PNorm = 36.8571, GNorm = 1.6735, lr_0 = 6.8952e-04
# Loss = 1.3511e-01, PNorm = 36.8937, GNorm = 0.9172, lr_0 = 6.8457e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.824667
#  19%|█▊        | 13/70 [01:38<07:00,  7.37s/it]Epoch 13
# Loss = 1.2152e-01, PNorm = 36.9364, GNorm = 0.6657, lr_0 = 6.7917e-04
# Loss = 1.7530e-01, PNorm = 36.9747, GNorm = 2.1645, lr_0 = 6.7429e-04
# Loss = 1.5896e-01, PNorm = 37.0084, GNorm = 0.9095, lr_0 = 6.6945e-04
# Loss = 1.5716e-01, PNorm = 37.0429, GNorm = 0.9356, lr_0 = 6.6465e-04
# Loss = 1.2871e-01, PNorm = 37.0891, GNorm = 2.8219, lr_0 = 6.5988e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.808968
#  20%|██        | 14/70 [01:45<06:50,  7.34s/it]Epoch 14
# Loss = 1.4280e-01, PNorm = 37.1231, GNorm = 1.0193, lr_0 = 6.5467e-04
# Loss = 1.2927e-01, PNorm = 37.1548, GNorm = 1.6331, lr_0 = 6.4997e-04
# Loss = 1.6756e-01, PNorm = 37.1898, GNorm = 1.0398, lr_0 = 6.4530e-04
# Loss = 1.2134e-01, PNorm = 37.2236, GNorm = 3.3063, lr_0 = 6.4067e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.809746
#  21%|██▏       | 15/70 [01:53<06:43,  7.34s/it]Epoch 15
# Loss = 1.1741e-01, PNorm = 37.2529, GNorm = 1.4833, lr_0 = 6.3561e-04
# Loss = 1.3016e-01, PNorm = 37.2906, GNorm = 1.2237, lr_0 = 6.3105e-04
# Loss = 1.2075e-01, PNorm = 37.3181, GNorm = 1.1990, lr_0 = 6.2652e-04
# Loss = 1.5111e-01, PNorm = 37.3385, GNorm = 0.9934, lr_0 = 6.2202e-04
# Loss = 1.4397e-01, PNorm = 37.3785, GNorm = 1.1275, lr_0 = 6.1756e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.870294
#  23%|██▎       | 16/70 [02:00<06:37,  7.37s/it]Epoch 16
# Loss = 1.5673e-01, PNorm = 37.4133, GNorm = 2.0594, lr_0 = 6.1312e-04
# Loss = 1.3150e-01, PNorm = 37.4459, GNorm = 1.2518, lr_0 = 6.0872e-04
# Loss = 1.2884e-01, PNorm = 37.4800, GNorm = 1.5930, lr_0 = 6.0435e-04
# Loss = 1.3521e-01, PNorm = 37.5069, GNorm = 0.8166, lr_0 = 6.0001e-04
# Loss = 1.2468e-01, PNorm = 37.5320, GNorm = 1.1211, lr_0 = 5.9571e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.823014
#  24%|██▍       | 17/70 [02:07<06:26,  7.29s/it]Epoch 17
# Loss = 1.4695e-01, PNorm = 37.5631, GNorm = 1.1582, lr_0 = 5.9100e-04
# Loss = 1.2513e-01, PNorm = 37.5938, GNorm = 1.4782, lr_0 = 5.8676e-04
# Loss = 1.1366e-01, PNorm = 37.6221, GNorm = 0.6399, lr_0 = 5.8255e-04
# Loss = 1.1884e-01, PNorm = 37.6521, GNorm = 1.1162, lr_0 = 5.7837e-04
# Loss = 1.3547e-01, PNorm = 37.6787, GNorm = 1.8560, lr_0 = 5.7421e-04
# Loss = 1.1505e-01, PNorm = 37.6805, GNorm = 2.0185, lr_0 = 5.7380e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.779017
#  26%|██▌       | 18/70 [02:15<06:18,  7.27s/it]Epoch 18
# Loss = 1.2159e-01, PNorm = 37.7062, GNorm = 1.5846, lr_0 = 5.6968e-04
# Loss = 1.3253e-01, PNorm = 37.7288, GNorm = 1.7004, lr_0 = 5.6559e-04
# Loss = 1.3428e-01, PNorm = 37.7602, GNorm = 1.5177, lr_0 = 5.6153e-04
# Loss = 1.0807e-01, PNorm = 37.7891, GNorm = 1.4025, lr_0 = 5.5750e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.779076
#  27%|██▋       | 19/70 [02:22<06:10,  7.27s/it]Epoch 19
# Loss = 1.2218e-01, PNorm = 37.8163, GNorm = 1.4493, lr_0 = 5.5310e-04
# Loss = 1.3573e-01, PNorm = 37.8443, GNorm = 1.2928, lr_0 = 5.4913e-04
# Loss = 1.0553e-01, PNorm = 37.8704, GNorm = 1.2877, lr_0 = 5.4519e-04
# Loss = 1.2403e-01, PNorm = 37.8937, GNorm = 0.5860, lr_0 = 5.4127e-04
# Loss = 1.2454e-01, PNorm = 37.9198, GNorm = 1.1310, lr_0 = 5.3739e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.762955
#  29%|██▊       | 20/70 [02:29<06:07,  7.35s/it]Epoch 20
# Loss = 8.2653e-02, PNorm = 37.9487, GNorm = 0.6301, lr_0 = 5.3353e-04
# Loss = 1.1093e-01, PNorm = 37.9714, GNorm = 1.0107, lr_0 = 5.2970e-04
# Loss = 1.0101e-01, PNorm = 37.9912, GNorm = 2.5037, lr_0 = 5.2590e-04
# Loss = 1.2137e-01, PNorm = 38.0155, GNorm = 1.2878, lr_0 = 5.2212e-04
# Loss = 1.1036e-01, PNorm = 38.0380, GNorm = 1.3879, lr_0 = 5.1837e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.794698
#  30%|███       | 21/70 [02:37<06:01,  7.37s/it]Epoch 21
# Loss = 1.1714e-01, PNorm = 38.0668, GNorm = 2.6728, lr_0 = 5.1428e-04
# Loss = 9.9188e-02, PNorm = 38.0914, GNorm = 1.9517, lr_0 = 5.1059e-04
# Loss = 9.9743e-02, PNorm = 38.1116, GNorm = 0.8184, lr_0 = 5.0692e-04
# Loss = 1.1492e-01, PNorm = 38.1319, GNorm = 1.4290, lr_0 = 5.0329e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.789380
#  31%|███▏      | 22/70 [02:44<05:52,  7.33s/it]Epoch 22
# Loss = 1.2997e-01, PNorm = 38.1563, GNorm = 2.9949, lr_0 = 4.9931e-04
# Loss = 9.3949e-02, PNorm = 38.1804, GNorm = 0.6238, lr_0 = 4.9573e-04
# Loss = 9.2345e-02, PNorm = 38.1992, GNorm = 0.6220, lr_0 = 4.9217e-04
# Loss = 1.2848e-01, PNorm = 38.2177, GNorm = 3.4454, lr_0 = 4.8864e-04
# Loss = 1.5692e-01, PNorm = 38.2475, GNorm = 2.1864, lr_0 = 4.8513e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.783881
#  33%|███▎      | 23/70 [02:51<05:42,  7.28s/it]Epoch 23
# Loss = 1.5802e-01, PNorm = 38.2756, GNorm = 4.8552, lr_0 = 4.8130e-04
# Loss = 1.2491e-01, PNorm = 38.3069, GNorm = 0.7451, lr_0 = 4.7784e-04
# Loss = 9.3347e-02, PNorm = 38.3289, GNorm = 0.4621, lr_0 = 4.7441e-04
# Loss = 9.7742e-02, PNorm = 38.3517, GNorm = 0.6454, lr_0 = 4.7101e-04
# Loss = 1.0542e-01, PNorm = 38.3766, GNorm = 0.8955, lr_0 = 4.6763e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.732994
#  34%|███▍      | 24/70 [02:58<05:33,  7.24s/it]Epoch 24
# Loss = 7.9829e-02, PNorm = 38.3951, GNorm = 1.2383, lr_0 = 4.6427e-04
# Loss = 9.3327e-02, PNorm = 38.4113, GNorm = 0.6013, lr_0 = 4.6094e-04
# Loss = 1.0482e-01, PNorm = 38.4313, GNorm = 0.8699, lr_0 = 4.5763e-04
# Loss = 1.0778e-01, PNorm = 38.4514, GNorm = 1.6185, lr_0 = 4.5434e-04
# Loss = 1.0797e-01, PNorm = 38.4681, GNorm = 0.6772, lr_0 = 4.5108e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.743891
#  36%|███▌      | 25/70 [03:06<05:29,  7.31s/it]Epoch 25
# Loss = 9.5313e-02, PNorm = 38.4812, GNorm = 1.1137, lr_0 = 4.4752e-04
# Loss = 9.8602e-02, PNorm = 38.5002, GNorm = 0.8551, lr_0 = 4.4431e-04
# Loss = 9.6893e-02, PNorm = 38.5143, GNorm = 1.3863, lr_0 = 4.4112e-04
# Loss = 8.9279e-02, PNorm = 38.5281, GNorm = 0.5694, lr_0 = 4.3795e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.736852
#  37%|███▋      | 26/70 [03:13<05:21,  7.30s/it]Epoch 26
# Loss = 6.7678e-02, PNorm = 38.5520, GNorm = 0.8972, lr_0 = 4.3450e-04
# Loss = 9.2904e-02, PNorm = 38.5687, GNorm = 2.3392, lr_0 = 4.3138e-04
# Loss = 1.0660e-01, PNorm = 38.5860, GNorm = 1.1101, lr_0 = 4.2828e-04
# Loss = 9.1742e-02, PNorm = 38.6042, GNorm = 0.8808, lr_0 = 4.2520e-04
# Loss = 1.0043e-01, PNorm = 38.6208, GNorm = 0.8720, lr_0 = 4.2215e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.764436
#  39%|███▊      | 27/70 [03:20<05:12,  7.26s/it]Epoch 27
# Loss = 9.5336e-02, PNorm = 38.6373, GNorm = 0.9453, lr_0 = 4.1912e-04
# Loss = 8.5797e-02, PNorm = 38.6620, GNorm = 1.3957, lr_0 = 4.1611e-04
# Loss = 8.9458e-02, PNorm = 38.6754, GNorm = 1.1591, lr_0 = 4.1313e-04
# Loss = 1.0046e-01, PNorm = 38.6928, GNorm = 0.6309, lr_0 = 4.1016e-04
# Loss = 9.4773e-02, PNorm = 38.7082, GNorm = 0.7688, lr_0 = 4.0722e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.725383
#  40%|████      | 28/70 [03:28<05:08,  7.35s/it]Epoch 28
# Loss = 9.3442e-02, PNorm = 38.7275, GNorm = 1.6252, lr_0 = 4.0400e-04
# Loss = 9.2210e-02, PNorm = 38.7463, GNorm = 0.8030, lr_0 = 4.0110e-04
# Loss = 8.7636e-02, PNorm = 38.7642, GNorm = 0.6192, lr_0 = 3.9822e-04
# Loss = 8.9209e-02, PNorm = 38.7744, GNorm = 1.0592, lr_0 = 3.9536e-04
# Loss = 8.1825e-02, PNorm = 38.7869, GNorm = 0.6355, lr_0 = 3.9253e-04
# Loss = 1.3972e-01, PNorm = 38.7887, GNorm = 1.6557, lr_0 = 3.9224e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.714019
#  41%|████▏     | 29/70 [03:35<05:01,  7.35s/it]Epoch 29
# Loss = 7.6693e-02, PNorm = 38.8059, GNorm = 1.0133, lr_0 = 3.8943e-04
# Loss = 9.2564e-02, PNorm = 38.8193, GNorm = 0.8125, lr_0 = 3.8663e-04
# Loss = 1.1081e-01, PNorm = 38.8370, GNorm = 2.0810, lr_0 = 3.8386e-04
# Loss = 8.7185e-02, PNorm = 38.8502, GNorm = 1.1982, lr_0 = 3.8110e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0
-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.681516
#  59%|█████▊    | 41/70 [05:03<03:37,  7.52s/it]Epoch 41
# Loss = 6.2357e-02, PNorm = 39.4800, GNorm = 1.7726, lr_0 = 2.5846e-04
# Loss = 6.6636e-02, PNorm = 39.4886, GNorm = 1.1726, lr_0 = 2.5660e-04
# Loss = 8.3695e-02, PNorm = 39.4975, GNorm = 1.0352, lr_0 = 2.5476e-04
# Loss = 6.9708e-02, PNorm = 39.5085, GNorm = 1.1797, lr_0 = 2.5293e-04
# Loss = 7.3542e-02, PNorm = 39.5176, GNorm = 0.9813, lr_0 = 2.5112e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.696565
#  60%|██████    | 42/70 [05:10<03:25,  7.34s/it]Epoch 42
# Loss = 6.1580e-02, PNorm = 39.5301, GNorm = 0.6909, lr_0 = 2.4913e-04
# Loss = 7.5229e-02, PNorm = 39.5400, GNorm = 1.9808, lr_0 = 2.4735e-04
# Loss = 7.9453e-02, PNorm = 39.5479, GNorm = 1.4620, lr_0 = 2.4557e-04
# Loss = 8.0148e-02, PNorm = 39.5602, GNorm = 2.3879, lr_0 = 2.4381e-04
# Loss = 9.6275e-02, PNorm = 39.5735, GNorm = 3.0711, lr_0 = 2.4206e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.676217
#  61%|██████▏   | 43/70 [05:17<03:15,  7.24s/it]Epoch 43
# Loss = 7.9069e-02, PNorm = 39.5836, GNorm = 0.8171, lr_0 = 2.4032e-04
# Loss = 7.6167e-02, PNorm = 39.5931, GNorm = 0.7546, lr_0 = 2.3859e-04
# Loss = 7.2612e-02, PNorm = 39.6006, GNorm = 0.9562, lr_0 = 2.3688e-04
# Loss = 5.9807e-02, PNorm = 39.6092, GNorm = 0.6043, lr_0 = 2.3518e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.687857
#  63%|██████▎   | 44/70 [05:24<03:08,  7.25s/it]Epoch 44
# Loss = 5.6589e-02, PNorm = 39.6191, GNorm = 0.5527, lr_0 = 2.3332e-04
# Loss = 7.5250e-02, PNorm = 39.6275, GNorm = 0.8354, lr_0 = 2.3165e-04
# Loss = 7.3857e-02, PNorm = 39.6350, GNorm = 0.9285, lr_0 = 2.2999e-04
# Loss = 6.3457e-02, PNorm = 39.6436, GNorm = 0.5335, lr_0 = 2.2834e-04
# Loss = 6.5209e-02, PNorm = 39.6502, GNorm = 0.8287, lr_0 = 2.2670e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.704878
#  64%|██████▍   | 45/70 [05:32<03:02,  7.28s/it]Epoch 45
# Loss = 7.8115e-02, PNorm = 39.6557, GNorm = 0.7179, lr_0 = 2.2491e-04
# Loss = 6.4631e-02, PNorm = 39.6600, GNorm = 0.6543, lr_0 = 2.2329e-04
# Loss = 6.8637e-02, PNorm = 39.6673, GNorm = 0.6398, lr_0 = 2.2169e-04
# Loss = 6.2841e-02, PNorm = 39.6761, GNorm = 0.5850, lr_0 = 2.2010e-04
# Loss = 7.0239e-02, PNorm = 39.6827, GNorm = 0.6287, lr_0 = 2.1852e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.681837
#  66%|██████▌   | 46/70 [05:39<02:53,  7.22s/it]Epoch 46
# Loss = 5.1233e-02, PNorm = 39.6912, GNorm = 0.5497, lr_0 = 2.1679e-04
# Loss = 6.6122e-02, PNorm = 39.6965, GNorm = 0.5090, lr_0 = 2.1524e-04
# Loss = 6.1574e-02, PNorm = 39.7049, GNorm = 1.0071, lr_0 = 2.1369e-04
# Loss = 6.4988e-02, PNorm = 39.7123, GNorm = 1.6045, lr_0 = 2.1216e-04
# Loss = 7.7896e-02, PNorm = 39.7177, GNorm = 1.2070, lr_0 = 2.1063e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.701270
#  67%|██████▋   | 47/70 [05:46<02:45,  7.19s/it]Epoch 47
# Loss = 6.5067e-02, PNorm = 39.7256, GNorm = 1.5720, lr_0 = 2.0912e-04
# Loss = 6.4648e-02, PNorm = 39.7355, GNorm = 0.7766, lr_0 = 2.0762e-04
# Loss = 6.4840e-02, PNorm = 39.7437, GNorm = 1.5366, lr_0 = 2.0613e-04
# Loss = 6.5447e-02, PNorm = 39.7482, GNorm = 1.2646, lr_0 = 2.0465e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.682304
#  69%|██████▊   | 48/70 [05:53<02:38,  7.18s/it]Epoch 48
# Loss = 4.6464e-02, PNorm = 39.7528, GNorm = 0.3124, lr_0 = 2.0304e-04
# Loss = 6.2096e-02, PNorm = 39.7592, GNorm = 0.5779, lr_0 = 2.0158e-04
# Loss = 6.3378e-02, PNorm = 39.7654, GNorm = 0.5231, lr_0 = 2.0013e-04
# Loss = 6.0767e-02, PNorm = 39.7719, GNorm = 1.1434, lr_0 = 1.9869e-04
# Loss = 6.4359e-02, PNorm = 39.7801, GNorm = 0.7023, lr_0 = 1.9727e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.690854
#  70%|███████   | 49/70 [06:00<02:32,  7.26s/it]Epoch 49
# Loss = 6.4422e-02, PNorm = 39.7856, GNorm = 0.9849, lr_0 = 1.9571e-04
# Loss = 6.7224e-02, PNorm = 39.7928, GNorm = 0.6367, lr_0 = 1.9431e-04
# Loss = 5.6776e-02, PNorm = 39.8009, GNorm = 1.4105, lr_0 = 1.9291e-04
# Loss = 6.9392e-02, PNorm = 39.8080, GNorm = 1.9743, lr_0 = 1.9153e-04
# Loss = 6.3815e-02, PNorm = 39.8128, GNorm = 1.0603, lr_0 = 1.9015e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.686139
#  71%|███████▏  | 50/70 [06:07<02:24,  7.22s/it]Epoch 50
# Loss = 7.6725e-02, PNorm = 39.8177, GNorm = 0.7654, lr_0 = 1.8879e-04
# Loss = 6.0947e-02, PNorm = 39.8239, GNorm = 0.7533, lr_0 = 1.8743e-04
# Loss = 6.1192e-02, PNorm = 39.8309, GNorm = 1.1497, lr_0 = 1.8609e-04
# Loss = 5.8542e-02, PNorm = 39.8379, GNorm = 0.8271, lr_0 = 1.8475e-04
# Loss = 6.1424e-02, PNorm = 39.8433, GNorm = 1.2281, lr_0 = 1.8342e-04
# Loss = 6.4425e-02, PNorm = 39.8435, GNorm = 0.8779, lr_0 = 1.8329e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0
-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.692407
#  81%|████████▏ | 57/70 [06:57<01:33,  7.17s/it]Epoch 57
# Loss = 6.1169e-02, PNorm = 39.9992, GNorm = 0.8295, lr_0 = 1.4820e-04
# Loss = 6.4553e-02, PNorm = 40.0034, GNorm = 1.7360, lr_0 = 1.4713e-04
# Loss = 5.6879e-02, PNorm = 40.0077, GNorm = 0.3903, lr_0 = 1.4608e-04
# Loss = 6.3913e-02, PNorm = 40.0120, GNorm = 1.0385, lr_0 = 1.4503e-04
# Loss = 5.9060e-02, PNorm = 40.0165, GNorm = 0.7135, lr_0 = 1.4399e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.676174
#  83%|████████▎ | 58/70 [07:04<01:25,  7.14s/it]Epoch 58
# Loss = 5.1680e-02, PNorm = 40.0223, GNorm = 1.1065, lr_0 = 1.4295e-04
# Loss = 6.9076e-02, PNorm = 40.0281, GNorm = 1.1649, lr_0 = 1.4193e-04
# Loss = 6.1301e-02, PNorm = 40.0315, GNorm = 0.5008, lr_0 = 1.4091e-04
# Loss = 5.9751e-02, PNorm = 40.0358, GNorm = 1.3254, lr_0 = 1.3990e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.699503
#  84%|████████▍ | 59/70 [07:11<01:18,  7.10s/it]Epoch 59
# ...
#  71%|███████▏  | 50/70 [07:55<03:09,  9.48s/it]Epoch 50
# Loss = 5.4927e-02, PNorm = 39.9082, GNorm = 0.5465, lr_0 = 1.8879e-04
# Loss = 5.7279e-02, PNorm = 39.9135, GNorm = 0.8521, lr_0 = 1.8743e-04
# Loss = 7.3303e-02, PNorm = 39.9202, GNorm = 0.8248, lr_0 = 1.8609e-04
# Loss = 7.0959e-02, PNorm = 39.9267, GNorm = 1.0393, lr_0 = 1.8475e-04
# Loss = 7.1351e-02, PNorm = 39.9319, GNorm = 0.5699, lr_0 = 1.8342e-04
# Loss = 1.5847e-01, PNorm = 39.9322, GNorm = 2.1162, lr_0 = 1.8329e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.832930
#  73%|███████▎  | 51/70 [08:05<03:00,  9.51s/it]Epoch 51
# Loss = 6.7823e-02, PNorm = 39.9390, GNorm = 0.9870, lr_0 = 1.8198e-04
# Loss = 6.3742e-02, PNorm = 39.9475, GNorm = 0.8955, lr_0 = 1.8067e-04
# Loss = 6.8941e-02, PNorm = 39.9519, GNorm = 0.3703, lr_0 = 1.7937e-04
# Loss = 6.2272e-02, PNorm = 39.9562, GNorm = 0.8483, lr_0 = 1.7808e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.868050
#  74%|███████▍  | 52/70 [08:14<02:50,  9.48s/it]Epoch 52
# Loss = 6.4830e-02, PNorm = 39.9626, GNorm = 1.3306, lr_0 = 1.7668e-04
# Loss = 5.9926e-02, PNorm = 39.9714, GNorm = 1.4700, lr_0 = 1.7541e-04
# Loss = 5.8437e-02, PNorm = 39.9787, GNorm = 0.9538, lr_0 = 1.7415e-04
# Loss = 5.5499e-02, PNorm = 39.9832, GNorm = 0.6233, lr_0 = 1.7290e-04
# Loss = 6.3900e-02, PNorm = 39.9865, GNorm = 0.8001, lr_0 = 1.7166e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.838071
#  76%|███████▌  | 53/70 [08:24<02:43,  9.60s/it]Epoch 53
# Loss = 5.7126e-02, PNorm = 39.9956, GNorm = 0.4081, lr_0 = 1.7030e-04
# Loss = 6.7015e-02, PNorm = 40.0021, GNorm = 0.7173, lr_0 = 1.6908e-04
# Loss = 5.6083e-02, PNorm = 40.0085, GNorm = 1.1815, lr_0 = 1.6787e-04
# Loss = 5.7482e-02, PNorm = 40.0137, GNorm = 0.8003, lr_0 = 1.6666e-04
# Loss = 6.2656e-02, PNorm = 40.0162, GNorm = 0.6644, lr_0 = 1.6547e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.822300
#  77%|███████▋  | 54/70 [08:33<02:32,  9.50s/it]Epoch 54
# Loss = 5.7657e-02, PNorm = 40.0210, GNorm = 0.9900, lr_0 = 1.6428e-04
# Loss = 5.3291e-02, PNorm = 40.0271, GNorm = 1.3346, lr_0 = 1.6310e-04
# Loss = 5.4263e-02, PNorm = 40.0320, GNorm = 0.6249, lr_0 = 1.6193e-04
# Loss = 6.3776e-02, PNorm = 40.0363, GNorm = 0.4642, lr_0 = 1.6077e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.814685
#  79%|███████▊  | 55/70 [08:43<02:22,  9.49s/it]Epoch 55
# Loss = 5.5743e-02, PNorm = 40.0423, GNorm = 0.6033, lr_0 = 1.5950e-04
# Loss = 6.3752e-02, PNorm = 40.0491, GNorm = 1.1806, lr_0 = 1.5835e-04
# Loss = 5.9048e-02, PNorm = 40.0537, GNorm = 2.3052, lr_0 = 1.5722e-04
# Loss = 5.1746e-02, PNorm = 40.0578, GNorm = 0.4272, lr_0 = 1.5609e-04
# Loss = 5.2643e-02, PNorm = 40.0615, GNorm = 0.6302, lr_0 = 1.5497e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.850847
#  80%|████████  | 56/70 [08:52<02:12,  9.49s/it]Epoch 56
# Loss = 4.7598e-02, PNorm = 40.0679, GNorm = 1.1513, lr_0 = 1.5374e-04
# Loss = 6.0160e-02, PNorm = 40.0749, GNorm = 0.6536, lr_0 = 1.5264e-04
# Loss = 5.9759e-02, PNorm = 40.0790, GNorm = 0.8626, lr_0 = 1.5154e-04
# Loss = 5.6603e-02, PNorm = 40.0844, GNorm = 0.6881, lr_0 = 1.5046e-04
# Loss = 5.6820e-02, PNorm = 40.0882, GNorm = 1.0260, lr_0 = 1.4938e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.811778
#  81%|████████▏ | 57/70 [09:02<02:03,  9.49s/it]Epoch 57
# Loss = 5.8687e-02, PNorm = 40.0953, GNorm = 1.0562, lr_0 = 1.4820e-04
# Loss = 5.0972e-02, PNorm = 40.1003, GNorm = 0.9724, lr_0 = 1.4713e-04
# Loss = 5.7403e-02, PNorm = 40.1056, GNorm = 1.0057, lr_0 = 1.4608e-04
# Loss = 6.2207e-02, PNorm = 40.1097, GNorm = 0.9689, lr_0 = 1.4503e-04
# Loss = 5.9953e-02, PNorm = 40.1132, GNorm = 0.6741, lr_0 = 1.4399e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.814208
#  83%|████████▎ | 58/70 [09:11<01:55,  9.59s/it]Epoch 58
# Loss = 5.5327e-02, PNorm = 40.1181, GNorm = 1.0011, lr_0 = 1.4295e-04
# Loss = 5.7812e-02, PNorm = 40.1237, GNorm = 1.3907, lr_0 = 1.4193e-04
# Loss = 4.8404e-02, PNorm = 40.1295, GNorm = 0.4304, lr_0 = 1.4091e-04
# Loss = 6.4547e-02, PNorm = 40.1330, GNorm = 0.7064, lr_0 = 1.3990e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.808000
#  84%|████████▍ | 59/70 [09:21<01:44,  9.53s/it]Epoch 59
# Loss = 4.9418e-02, PNorm = 40.1385, GNorm = 0.5106, lr_0 = 1.3879e-04
# Loss = 6.0478e-02, PNorm = 40.1418, GNorm = 1.6436, lr_0 = 1.3780e-04
# Loss = 6.3307e-02, PNorm = 40.1475, GNorm = 1.0740, lr_0 = 1.3681e-04
# Loss = 5.2057e-02, PNorm = 40.1531, GNorm = 0.4210, lr_0 = 1.3582e-04
# Loss = 5.1822e-02, PNorm = 40.1573, GNorm = 0.4310, lr_0 = 1.3485e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.805175
#  86%|████████▌ | 60/70 [09:30<01:34,  9.49s/it]Epoch 60
# Loss = 6.1544e-02, PNorm = 40.1637, GNorm = 0.6204, lr_0 = 1.3379e-04
# Loss = 4.8993e-02, PNorm = 40.1680, GNorm = 0.4390, lr_0 = 1.3282e-04
# Loss = 7.4289e-02, PNorm = 40.1709, GNorm = 1.8538, lr_0 = 1.3187e-04
# Loss = 5.4767e-02, PNorm = 40.1760, GNorm = 0.6749, lr_0 = 1.3092e-04
# Loss = 5.5123e-02, PNorm = 40.1819, GNorm = 0.9802, lr_0 = 1.2998e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.794156
#  87%|████████▋ | 61/70 [09:40<01:25,  9.50s/it]Epoch 61
# Loss = 5.8795e-02, PNorm = 40.1860, GNorm = 0.5921, lr_0 = 1.2896e-04
# Loss = 5.8608e-02, PNorm = 40.1888, GNorm = 0.5538, lr_0 = 1.2803e-04
# Loss = 5.6874e-02, PNorm = 40.1935, GNorm = 0.7766, lr_0 = 1.2711e-04
# Loss = 5.1678e-02, PNorm = 40.1970, GNorm = 1.3947, lr_0 = 1.2620e-04
# Loss = 5.3250e-02, PNorm = 40.2022, GNorm = 1.9344, lr_0 = 1.2530e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.791812
#  89%|████████▊ | 62/70 [09:50<01:16,  9.59s/it]Epoch 62
# Loss = 5.8325e-02, PNorm = 40.2058, GNorm = 1.5960, lr_0 = 1.2440e-04
# Loss = 5.5713e-02, PNorm = 40.2101, GNorm = 0.6306, lr_0 = 1.2350e-04
# Loss = 4.6687e-02, PNorm = 40.2149, GNorm = 1.4859, lr_0 = 1.2262e-04
# Loss = 5.4014e-02, PNorm = 40.2181, GNorm = 0.9168, lr_0 = 1.2174e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.827127
#  90%|█████████ | 63/70 [09:59<01:06,  9.52s/it]Epoch 63
# Loss = 4.0257e-02, PNorm = 40.2216, GNorm = 0.8137, lr_0 = 1.2078e-04
# Loss = 5.1586e-02, PNorm = 40.2258, GNorm = 1.2850, lr_0 = 1.1991e-04
# Loss = 5.3641e-02, PNorm = 40.2303, GNorm = 0.7128, lr_0 = 1.1905e-04
# Loss = 5.5789e-02, PNorm = 40.2360, GNorm = 0.5925, lr_0 = 1.1819e-04
# Loss = 6.1511e-02, PNorm = 40.2394, GNorm = 0.6255, lr_0 = 1.1734e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.806200
#  91%|█████████▏| 64/70 [10:08<00:57,  9.50s/it]Epoch 64
# Loss = 5.2454e-02, PNorm = 40.2437, GNorm = 0.4860, lr_0 = 1.1642e-04
# Loss = 5.2416e-02, PNorm = 40.2466, GNorm = 0.6115, lr_0 = 1.1558e-04
# Loss = 4.7271e-02, PNorm = 40.2508, GNorm = 1.1113, lr_0 = 1.1475e-04
# Loss = 5.9584e-02, PNorm = 40.2542, GNorm = 0.7672, lr_0 = 1.1393e-04
# Loss = 6.1206e-02, PNorm = 40.2570, GNorm = 1.0454, lr_0 = 1.1311e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.849497
#  93%|█████████▎| 65/70 [10:18<00:47,  9.49s/it]Epoch 65
# Loss = 5.9145e-02, PNorm = 40.2607, GNorm = 1.0240, lr_0 = 1.1222e-04
# Loss = 5.1845e-02, PNorm = 40.2658, GNorm = 0.5402, lr_0 = 1.1141e-04
# Loss = 5.6104e-02, PNorm = 40.2703, GNorm = 0.5228, lr_0 = 1.1061e-04
# Loss = 4.9709e-02, PNorm = 40.2738, GNorm = 0.4935, lr_0 = 1.0982e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.810540
#  94%|█████████▍| 66/70 [10:28<00:38,  9.62s/it]Epoch 66
# Loss = 5.4060e-02, PNorm = 40.2767, GNorm = 0.7852, lr_0 = 1.0903e-04
# Loss = 4.2826e-02, PNorm = 40.2785, GNorm = 0.4845, lr_0 = 1.0825e-04
# Loss = 5.2623e-02, PNorm = 40.2807, GNorm = 1.3213, lr_0 = 1.0747e-04
# Loss = 6.1686e-02, PNorm = 40.2847, GNorm = 0.5533, lr_0 = 1.0670e-04
# Loss = 5.4850e-02, PNorm = 40.2887, GNorm = 0.4448, lr_0 = 1.0593e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.807334
#  96%|█████████▌| 67/70 [10:37<00:28,  9.55s/it]Epoch 67
# Loss = 4.5846e-02, PNorm = 40.2938, GNorm = 0.6530, lr_0 = 1.0510e-04
# Loss = 5.3268e-02, PNorm = 40.2963, GNorm = 0.7315, lr_0 = 1.0434e-04
# Loss = 4.9804e-02, PNorm = 40.3008, GNorm = 0.6222, lr_0 = 1.0359e-04
# Loss = 4.5327e-02, PNorm = 40.3045, GNorm = 0.5607, lr_0 = 1.0285e-04
# Loss = 5.5247e-02, PNorm = 40.3083, GNorm = 0.7277, lr_0 = 1.0211e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.805191
#  97%|█████████▋| 68/70 [10:47<00:19,  9.54s/it]Epoch 68
# Loss = 5.4718e-02, PNorm = 40.3110, GNorm = 0.8786, lr_0 = 1.0131e-04
# Loss = 4.7151e-02, PNorm = 40.3132, GNorm = 0.5690, lr_0 = 1.0058e-04
# Loss = 5.4155e-02, PNorm = 40.3171, GNorm = 0.5472, lr_0 = 1.0000e-04
# Loss = 4.6457e-02, PNorm = 40.3204, GNorm = 0.4221, lr_0 = 1.0000e-04
# Loss = 5.7010e-02, PNorm = 40.3247, GNorm = 1.0060, lr_0 = 1.0000e-04
# Loss = 4.0659e-02, PNorm = 40.3253, GNorm = 1.0977, lr_0 = 1.0000e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.812788
#  99%|█████████▊| 69/70 [10:56<00:09,  9.51s/it]Epoch 69
# Loss = 5.5346e-02, PNorm = 40.3293, GNorm = 1.5808, lr_0 = 1.0000e-04
# Loss = 5.2375e-02, PNorm = 40.3315, GNorm = 1.0127, lr_0 = 1.0000e-04
# Loss = 5.3343e-02, PNorm = 40.3350, GNorm = 0.4160, lr_0 = 1.0000e-04
# Loss = 5.7035e-02, PNorm = 40.3388, GNorm = 0.6266, lr_0 = 1.0000e-04
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.825223
# 100%|██████████| 70/70 [11:06<00:00,  9.52s/it]
# Model 0 best validation rmse = 0.784352 on epoch 46
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.670533
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.670533
# 10-fold cross validation
# 	Seed 0 ==> test rmse = 0.687873
# 	Seed 1 ==> test rmse = 0.691141
# 	Seed 2 ==> test rmse = 0.627082
# 	Seed 3 ==> test rmse = 0.665542
# 	Seed 4 ==> test rmse = 0.595138
# 	Seed 5 ==> test rmse = 0.761910
# 	Seed 6 ==> test rmse = 0.735156
# 	Seed 7 ==> test rmse = 0.673269
# 	Seed 8 ==> test rmse = 0.742060
# 	Seed 9 ==> test rmse = 0.670533
# Overall test rmse = 0.684970 +/- 0.048875
# Elapsed time = 1:39:43

# %%
arguments = [
    '--test_path', 'test_checkpoints_splits/fold_0/test_smiles.csv',
    '--preds_path', 'test_preds_splits.csv',
    '--checkpoint_dir', 'test_checkpoints_splits',
    '--num_workers', '0',
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 296it [00:00, 295176.89it/s]
# 100%|██████████| 296/296 [00:00<00:00, 295176.89it/s]
# Validating SMILES
# Test size = 296
#   0%|          | 0/10 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  10%|█         | 1/10 [00:00<00:05,  1.70it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  20%|██        | 2/10 [00:01<00:04,  1.64it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  30%|███       | 3/10 [00:01<00:04,  1.67it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  40%|████      | 4/10 [00:02<00:03,  1.66it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  50%|█████     | 5/10 [00:03<00:03,  1.67it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  60%|██████    | 6/10 [00:03<00:02,  1.37it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  70%|███████   | 7/10 [00:04<00:02,  1.45it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  80%|████████  | 8/10 [00:05<00:01,  1.52it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#  90%|█████████ | 9/10 [00:05<00:00,  1.54it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# 100%|██████████| 10/10 [00:06<00:00,  1.56it/s]
# Saving predictions to test_preds_splits.csv
# Elapsed time = 0:00:07

# %%
df = pd.read_csv('test_checkpoints_splits/fold_0/test_full.csv')
df['preds'] = [x[0] for x in preds]
df.columns = ['Smiles', 'pIC50', 'preds']
df
# Out:
#                                                 Smiles      pIC50     preds
# 0    COc1nc(N(C)C)ncc1-c1cc2c(n1C(C)C)C(c1ccc(Cl)c(...   9.856985  9.840960
# 1    COc1ncc(-c2cc3c(n2C(C)C)[C@@H](c2ccc(Cl)cc2)N(...   7.547907  6.742962
# 2    COc1ncc(-c2cc3c(n2C(C)C)[C@H](c2ccc(Cl)cc2)N(c...  10.060481  9.791978
# 3    COc1nc(N(C)C)ncc1-c1cc2c(n1C(C)C)C(c1ccc(Cl)cc...   9.636388  9.923479
# 4    COc1nc(N(C)C)ncc1-c1cc2c(n1C(C)C)C(c1ccc(Cl)cc...   9.863279  9.818044
# ..                                                 ...        ...       ...
# 291  O=C1c2ccccc2C(OCCNC(=O)C(F)(F)F)(c2ccccc2)N1Cc...   3.388277  3.387811
# 292  O=C1c2ccccc2C(OCCS(=O)(=O)[O-])(c2ccccc2)N1Cc1...   3.462181  3.547298
# 293  CCC1CCC(Cn2c(N3CCO[C@@H]4CCC[C@H]43)nc3cc(-c4n...   7.795880  7.660488
# 294  CCC[C@H]1N(C(=O)c2c(C(F)(F)F)ccc[n+]2[O-])CCC[...   7.657577  7.250276
# 295  C[C@H]1CC[C@H](Cn2c(N3CCOC4CC43)nc3cc(-c4noc(=...   7.366532  8.414609
#
# [296 rows x 3 columns]

# %%
plot_parity(df.pIC50, df.preds)
# Out:
# c:\Users\noviasari\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # Ensembling and Uncertainty

# %%
arguments = [
    '--data_path', 'data/reaction_regression.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'test_checkpoints_ensemble',
    '--epochs', '5',
    '--reaction',
    '--save_smiles_splits',
    '--ensemble_size', '5',
    '--split_type', 'scaffold_balanced'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-8f687a13-fd1d-4bb6-bf15-8368444c40f1.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/reaction_regression.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 5,
#  'epochs': 5,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': True,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_ensemble',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['AAM'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'scaffold_balanced',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['ea'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Setting molecule featurization parameters to default.
# Loading data
# 500it [00:00, 86284.80it/s]
# 100%|██████████| 500/500 [00:00<00:00, 60688.51it/s]
# 100%|██████████| 500/500 [00:00<00:00, 77166.43it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 100%|██████████| 500/500 [00:00<00:00, 16531.62it/s]
# Total scaffolds = 203 | train scaffolds = 147 | val scaffolds = 29 | test scaffolds = 27
# Label averages per scaffold, in decreasing order of scaffold frequency,capped at 10 scaffolds and 20 labels:
# Scaffold 0
# Task 0: count = 141 | target average = 8.010435
#
#
# Scaffold 1
# Task 0: count = 13 | target average = 9.241358
#
#
# Scaffold 2
# Task 0: count = 7 | target average = 7.232327
#
#
# Scaffold 3
# Task 0: count = 7 | target average = 7.289696
#
#
# Scaffold 4
# Task 0: count = 7 | target average = 6.381221
#
#
# Scaffold 5
# Task 0: count = 6 | target average = 6.927956
#
#
# Scaffold 6
# Task 0: count = 6 | target average = 8.997394
#
#
# Scaffold 7
# Task 0: count = 5 | target average = 7.520033
#
#
# Scaffold 8
# Task 0: count = 5 | target average = 8.068549
#
#
# Scaffold 9
# Task 0: count = 4 | target average = 7.458364
#
#
# 500it [00:00, 90927.51it/s]
# Total size = 500 | train size = 400 | val size = 50 | test size = 50
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=193, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=465, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 378,601
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 17.99it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.11it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.64it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.28it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.732327
#  20%|██        | 1/5 [00:00<00:02,  1.65it/s]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 9.6142e-01, PNorm = 34.6714, GNorm = 2.1701, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00, 17.16it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.37it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 16.45it/s]
# 100%|██████████| 8/8 [00:00<00:00, 16.97it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.342255
#  40%|████      | 2/5 [00:01<00:01,  1.64it/s]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.13it/s]Loss = 9.8149e-01, PNorm = 34.7063, GNorm = 1.2760, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00, 16.84it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 16.66it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.15it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.459109
#  60%|██████    | 3/5 [00:01<00:01,  1.72it/s]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 12.02it/s]
#  50%|█████     | 4/8 [00:00<00:00, 11.96it/s]Loss = 7.0097e-01, PNorm = 34.7281, GNorm = 3.2559, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 11.97it/s]
# 100%|██████████| 8/8 [00:00<00:00, 11.94it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.278640
#  80%|████████  | 4/5 [00:02<00:00,  1.40it/s]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 12.26it/s]
#  50%|█████     | 4/8 [00:00<00:00, 11.79it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 11.56it/s]Loss = 6.5832e-01, PNorm = 34.7370, GNorm = 1.5438, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:00<00:00, 11.57it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.200886
# 100%|██████████| 5/5 [00:03<00:00,  1.39it/s]
# Model 0 best validation rmse = 2.200886 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 0 test rmse = 2.063817
# Building model 1
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=193, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=465, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 378,601
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 11.51it/s]
#  50%|█████     | 4/8 [00:00<00:00, 11.06it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 11.58it/s]
# 100%|██████████| 8/8 [00:00<00:00, 11.52it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.382831
#  20%|██        | 1/5 [00:00<00:03,  1.09it/s]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 6.9498e-01, PNorm = 34.7268, GNorm = 1.8911, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00, 11.49it/s]
#  50%|█████     | 4/8 [00:00<00:00, 11.24it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 12.58it/s]
# 100%|██████████| 8/8 [00:00<00:00, 14.08it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.378330
#  40%|████      | 2/5 [00:01<00:02,  1.20it/s]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.38it/s]Loss = 9.4992e-01, PNorm = 34.7565, GNorm = 6.6179, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00, 18.08it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.48it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.40it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.331827
#  60%|██████    | 3/5 [00:02<00:01,  1.38it/s]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.36it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.71it/s]Loss = 6.8234e-01, PNorm = 34.7775, GNorm = 1.9858, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 17.66it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.26it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.327268
#  80%|████████  | 4/5 [00:02<00:00,  1.48it/s]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 17.77it/s]
#  50%|█████     | 4/8 [00:00<00:00, 16.47it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.21it/s]Loss = 6.7731e-01, PNorm = 34.7858, GNorm = 2.4888, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:00<00:00, 16.80it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.261885
# 100%|██████████| 5/5 [00:03<00:00,  1.42it/s]
# Model 1 best validation rmse = 2.261885 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 1 test rmse = 2.100716
# Building model 2
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=193, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=465, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 378,601
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.55it/s]
#  50%|█████     | 4/8 [00:00<00:00, 18.25it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.51it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.26it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.236768
#  20%|██        | 1/5 [00:00<00:02,  1.66it/s]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 7.8392e-01, PNorm = 34.6746, GNorm = 2.7400, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00, 17.40it/s]
#  50%|█████     | 4/8 [00:00<00:00, 16.99it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 16.92it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.33it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.621285
#  40%|████      | 2/5 [00:01<00:01,  1.76it/s]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 16.19it/s]Loss = 8.8711e-01, PNorm = 34.7106, GNorm = 7.5942, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00, 16.30it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 16.54it/s]
# 100%|██████████| 8/8 [00:00<00:00, 16.64it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.178063
#  60%|██████    | 3/5 [00:01<00:01,  1.67it/s]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 16.72it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.42it/s]Loss = 6.6988e-01, PNorm = 34.7298, GNorm = 2.6633, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 17.52it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.32it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.198801
#  80%|████████  | 4/5 [00:02<00:00,  1.72it/s]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 17.50it/s]
#  50%|█████     | 4/8 [00:00<00:00, 16.46it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 16.66it/s]Loss = 6.1597e-01, PNorm = 34.7378, GNorm = 3.5316, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:00<00:00, 16.83it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.209044
# 100%|██████████| 5/5 [00:02<00:00,  1.72it/s]
# Model 2 best validation rmse = 2.178063 on epoch 2
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 2 test rmse = 2.126568
# Building model 3
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=193, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=465, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 378,601
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 15.05it/s]
#  50%|█████     | 4/8 [00:00<00:00, 15.89it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 15.92it/s]
# 100%|██████████| 8/8 [00:00<00:00, 16.37it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.507891
#  20%|██        | 1/5 [00:00<00:02,  1.52it/s]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 1.0369e+00, PNorm = 34.6048, GNorm = 1.8233, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00, 17.51it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.31it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.61it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.90it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.420495
#  40%|████      | 2/5 [00:01<00:01,  1.57it/s]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.17it/s]Loss = 8.9386e-01, PNorm = 34.6320, GNorm = 5.4624, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00, 15.81it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 16.63it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.10it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.388413
#  60%|██████    | 3/5 [00:01<00:01,  1.59it/s]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.68it/s]
#  50%|█████     | 4/8 [00:00<00:00, 18.69it/s]Loss = 7.7755e-01, PNorm = 34.6502, GNorm = 5.8818, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 16.94it/s]
# 100%|██████████| 8/8 [00:00<00:00, 16.90it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.239898
#  80%|████████  | 4/5 [00:02<00:00,  1.60it/s]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 18.58it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.79it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.73it/s]Loss = 6.7354e-01, PNorm = 34.6580, GNorm = 2.4950, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:00<00:00, 17.42it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.189930
# 100%|██████████| 5/5 [00:03<00:00,  1.60it/s]
# Model 3 best validation rmse = 2.189930 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 3 test rmse = 2.075962
# Building model 4
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=193, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=465, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 378,601
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 16.98it/s]
#  50%|█████     | 4/8 [00:00<00:00, 17.78it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 17.15it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.50it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.780604
#  20%|██        | 1/5 [00:00<00:02,  1.65it/s]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 9.4477e-01, PNorm = 34.6048, GNorm = 0.9831, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00, 17.50it/s]
#  50%|█████     | 4/8 [00:00<00:00, 16.50it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 15.53it/s]
# 100%|██████████| 8/8 [00:00<00:00, 14.02it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.337362
#  40%|████      | 2/5 [00:01<00:02,  1.44it/s]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 11.68it/s]Loss = 7.8064e-01, PNorm = 34.6384, GNorm = 1.7224, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00, 11.20it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 10.85it/s]
# 100%|██████████| 8/8 [00:00<00:00, 10.86it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.411323
#  60%|██████    | 3/5 [00:02<00:01,  1.32it/s]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 11.56it/s]
#  50%|█████     | 4/8 [00:00<00:00, 11.93it/s]Loss = 7.3826e-01, PNorm = 34.6613, GNorm = 4.0008, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 11.89it/s]
# 100%|██████████| 8/8 [00:00<00:00, 11.80it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.280935
#  80%|████████  | 4/5 [00:03<00:00,  1.24it/s]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 11.10it/s]
#  50%|█████     | 4/8 [00:00<00:00, 11.57it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 11.66it/s]Loss = 6.4870e-01, PNorm = 34.6701, GNorm = 5.0483, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:00<00:00, 11.20it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 2.204269
# 100%|██████████| 5/5 [00:04<00:00,  1.24it/s]
# Model 4 best validation rmse = 2.204269 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 4 test rmse = 2.108382
# Ensemble test rmse = 2.067441
# 1-fold cross validation
# 	Seed 0 ==> test rmse = 2.067441
# Overall test rmse = 2.067441 +/- 0.000000
# Elapsed time = 0:00:19

# %%
arguments = [
    '--test_path', 'test_checkpoints_ensemble/fold_0/test_smiles.csv',
    '--preds_path', 'test_preds_ensemble.csv',
    '--checkpoint_dir', 'test_checkpoints_ensemble',
    '--ensemble_variance'
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 50it [00:00, 78251.94it/s]
# 100%|██████████| 50/50 [00:00<00:00, 109626.35it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating SMILES
# Test size = 50
#   0%|          | 0/5 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.65it/s]
#  20%|██        | 1/5 [00:00<00:01,  2.11it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.53it/s]
#  40%|████      | 2/5 [00:00<00:01,  2.12it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
#  60%|██████    | 3/5 [00:01<00:00,  2.08it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
#  80%|████████  | 4/5 [00:01<00:00,  2.07it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.37it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2
# 29  [C:1]([C@:2]12[C:3]([H:10])([H:11])[C:4]([H:12...   8.116722
# 30  [C:1]([C@@:2]1([H:11])[O:3][C:4]([H:12])([H:13...   8.908027
# 31  [C:1]([C@@:2]1([H:11])[O:3][C:4]([H:12])([H:13...   7.425850
# 32  [O:1]=[C:2]1[C:3]([H:8])([H:9])[O:4][C@@:5]2([...   8.702798
# 33  [C:1]([C@@:2]1([C:3]([O:4][H:12])([H:10])[H:11...   7.963273
# 34  [C:1]1([H:6])([H:7])[C:2]([H:8])([H:9])[C@@:3]...   8.077995
# 35  [N:1]#[C:2][C@@:3]1([H:7])[C:4]([H:8])([H:9])[...   7.693681
# 36  [C:1]1([H:8])([H:9])[O:2][C@@:3]2([H:10])[C:4]...   7.850417
# 37  [C:1]1([H:8])([H:9])[O:2][C@@:3]2([H:10])[C:4]...   7.768584
# 38  [C:1]([C:2]#[C:3][C:4]([N:5]1[C:6]([H:13])([H:...   8.004091
# 39  [N:1]([C:2](=[O:3])[C:4]([N:5]1[C:6]([H:12])([...   7.967761
# 40  [C:1]([C:2]#[C:3][C:4]([N:5]1[C:6]([H:13])([H:...   9.012047
# 41  [N:1]([C:2](=[O:3])[C:4]([N:5]1[C:6]([H:12])([...   7.712333
# 42  [C:1]([C@@:2]1([H:11])[C:3]([H:12])([H:13])[C:...   7.955681
# 43  [C:1]([C@@:2]1([H:10])[C:3]([H:11])([H:12])[C:...   9.677749
# 44  [C:1]([C@@:2]1([H:10])[C:3]([H:11])([H:12])[C:...   8.062699
# 45  [C:1]([C:2]1([C:3]([O:4][H:12])([H:10])[H:11])...  10.491706
# 46  [C:1]1([H:7])([H:8])[C:2]([H:9])([H:10])[C:3](...   9.052074
# 47  [C:1](#[C:2][C:3]1([H:8])[C:4]([H:9])([H:10])[...   8.012644
# 48  [C:1]([O:2][C@@:3]1([H:11])[C:4]([H:12])([H:13...   7.975821
# 49  [O:1]([C:2]([C:3]1([H:10])[C:4]([H:11])([H:12]...   9.594182
#
#     ea_ensemble_uncal_var
# 0                0.051191
# 1                0.362828
# 2                0.073829
# 3                0.356629
# 4                0.174254
# 5                0.116326
# 6                0.044275
# 7                0.175392
# 8                0.310400
# 9                0.050446
# 10               0.076409
# 11               0.107827
# 12               0.374892
# 13               0.162265
# 14               0.278382
# 15               0.084502
# 16               0.048565
# 17               0.014819
# 18               0.024714
# 19               0.011509
# 20               0.049530
# 21               0.023132
# 22               0.064748
# 23               0.030620
# 24               0.162666
# 25               0.057869
# 26               0.051980
# 27               0.036442
# 28               0.183325
# 29               0.182136
# 30               0.265048
# 31               0.088779
# 32               0.237794
# 33               0.081806
# 34               0.145824
# 35               0.044768
# 36               0.090569
# 37               0.075748
# 38               0.077657
# 39               0.065627
# 40               0.067033
# 41               0.052295
# 42               0.023752
# 43               0.084125
# 44               0.030905
# 45               0.295304
# 46               0.064273
# 47               0.064509
# 48               0.075249
# 49               0.106705

# %%
df = pd.read_csv('test_checkpoints_ensemble/fold_0/test_full.csv')
plot_parity(df.ea, preds_df.ea, preds_df.ea_ensemble_uncal_var)

# %% [markdown]
# # Fingerprint

# %%
arguments = [
    '--test_path', 'top_5_fromdocking.csv',
    '--preds_path', 'test_preds_fingerprint.csv',
    '--checkpoint_dir', 'test_checkpoints_reg',
    '--fingerprint_type', 'MPN'
]

args = chemprop.args.FingerprintArgs().parse_args(arguments)
preds = chemprop.train.molecule_fingerprint.molecule_fingerprint(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 5it [00:00, 21098.11it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21465.22it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating SMILES
# Test size = 5
# Encoding smiles into a fingerprint vector from 5 models.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.50it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.07it/s]
#  40%|████      | 2/5 [00:01<00:01,  1.51it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
#  60%|██████    | 3/5 [00:01<00:01,  1.56it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
#  80%|████████  | 4/5 [00:02<00:00,  1.57it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.42it/s]
# 100%|██████████| 5/5 [00:03<00:00,  1.42it/s]
# Saving predictions to test_preds_fingerprint.csv
# Elapsed time = 0:00:04

# %%
preds.squeeze().shape
# Out:
# (23, 300, 5)

# %%
df = pd.read_csv('std_niv_binary.csv')

pca = PCA(n_components=2)
pca_xy = pca.fit_transform(preds.squeeze())
plt.scatter(pca_xy[:,0], pca_xy[:,1], s=30, c=df.logSolubility, edgecolor='w')
plt.colorbar(label='logSolubility')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-97a71a14b44f> in <cell line: 4>()
#       2
#       3 pca = PCA(n_components=2)
# ----> 4 pca_xy = pca.fit_transform(preds.squeeze())
#       5 plt.scatter(pca_xy[:,0], pca_xy[:,1], s=30, c=df.logSolubility, edgecolor='w')
#       6 plt.colorbar(label='logSolubility')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     460         self._validate_params()
#     461
# --> 462         U, S, Vt = self._fit(X)
#     463         U = U[:, : self.n_components_]
#     464
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     483             )
#     484
# --> 485         X = self._validate_data(
#     486             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913             )
#     914         if not allow_nd and array.ndim >= 3:
# --> 915             raise ValueError(
#     916                 "Found array with dim %d. %s expected <= 2."
#     917                 % (array.ndim, estimator_name)
#
# ValueError: Found array with dim 3. PCA expected <= 2.

# %% [markdown]
# # Spectra

# %%
arguments = [
    '--data_path', 'data/spectra.csv',
    '--dataset_type', 'spectra',
    '--save_dir', 'test_checkpoints_spectra',
    '--epochs', '5',
    '--features_path', 'data/spectra_features.csv',
    '--split_type', 'random_with_repeated_smiles',
    '--save_smiles_splits'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-8f687a13-fd1d-4bb6-bf15-8368444c40f1.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/spectra.csv',
#  'data_weights_path': None,
#  'dataset_type': 'spectra',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 5,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': ['data/spectra_features.csv'],
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'sid',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'sid',
#  'metrics': ['sid'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 6,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_spectra',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random_with_repeated_smiles',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['400', '402', '404', '406', '408', '410'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Setting molecule featurization parameters to default.
# Loading data
# 200it [00:00, 50063.31it/s]
# 100%|██████████| 200/200 [00:00<00:00, 57197.65it/s]
# 100%|██████████| 200/200 [00:00<00:00, 11280.32it/s]
# Number of tasks = 6
# Fold 0
# Splitting data with seed 0
# 0it [00:00, ?it/s]Warning: Repeated SMILES found in data, pickle file of split indices cannot distinguish entries and will not be generated.
# 1it [00:00, 756.55it/s]
# Total size = 200 | train size = 160 | val size = 20 | test size = 20
# Normalizing spectra and excluding spectra regions based on phase
# 100%|██████████| 4/4 [00:00<00:00, 2786.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 2413.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 3575.71it/s]
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=305, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=6, bias=True)
#     (5): nn_exp()
#   )
# )
# Number of parameters = 358,206
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:00<00:00,  7.61it/s]
#  50%|█████     | 2/4 [00:00<00:00,  8.04it/s]
#  75%|███████▌  | 3/4 [00:00<00:00,  8.32it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2807.43it/s]
# Validation sid = 0.038611
#  20%|██        | 1/5 [00:00<00:02,  1.84it/s]Epoch 1
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#  50%|█████     | 2/4 [00:00<00:00, 11.18it/s]
# 100%|██████████| 4/4 [00:00<00:00, 13.65it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2309.64it/s]
# Validation sid = 0.008126
#  40%|████      | 2/5 [00:00<00:01,  2.06it/s]Epoch 2
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:00<00:00,  9.98it/s]
#  50%|█████     | 2/4 [00:00<00:00,  9.01it/s]
# 100%|██████████| 4/4 [00:00<00:00, 12.72it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1281.09it/s]
# Validation sid = 0.005895
#  60%|██████    | 3/5 [00:01<00:00,  2.05it/s]Epoch 3
#
#   0%|          | 0/4 [00:00<?, ?it/s]Loss = 1.3642e-03, PNorm = 34.2052, GNorm = 0.0428, lr_0 = 1.2915e-04
#
#  25%|██▌       | 1/4 [00:00<00:00,  9.24it/s]
#  75%|███████▌  | 3/4 [00:00<00:00, 10.44it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2284.48it/s]
# Validation sid = 0.003364
#  80%|████████  | 4/5 [00:01<00:00,  2.09it/s]Epoch 4
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#  50%|█████     | 2/4 [00:00<00:00, 10.90it/s]
# 100%|██████████| 4/4 [00:00<00:00, 13.02it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1955.39it/s]
# Validation sid = 0.002056
# 100%|██████████| 5/5 [00:02<00:00,  2.08it/s]
# Model 0 best validation sid = 0.002056 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# 100%|██████████| 1/1 [00:00<00:00, 3483.64it/s]
# Model 0 test sid = 0.003194
# 100%|██████████| 1/1 [00:00<00:00, 2890.63it/s]
# Ensemble test sid = 0.003194
# 1-fold cross validation
# 	Seed 0 ==> test sid = 0.003194
# Overall test sid = 0.003194 +/- 0.000000
# Elapsed time = 0:00:03

# %%
arguments = [
    '--test_path', 'test_checkpoints_spectra/fold_0/test_smiles.csv',
    '--preds_path', 'test_preds_spectra.csv',
    '--checkpoint_dir', 'test_checkpoints_spectra',
    '--features_path', 'data/spectra_features.csv'
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 20it [00:00, 21715.27it/s]
# 100%|██████████| 20/20 [00:00<00:00, 34923.43it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating SMILES
# Test size = 20
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.55it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1095.40it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Saving predictions to test_preds_spectra.csv
# Elapsed time = 0:00:01

# %% [markdown]
# # Pretraining / Transfer Learning

# %%
arguments = [
    '--data_path', 'data/regression.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'test_checkpoints_transfer',
    '--epochs', '5',
    '--save_smiles_splits'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-8f687a13-fd1d-4bb6-bf15-8368444c40f1.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/regression.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 5,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_transfer',
#  'save_preds': False,
#  'save_smiles_splits': True,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['logSolubility'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Setting molecule featurization parameters to default.
# Loading data
# 500it [00:00, 111443.94it/s]
# 100%|██████████| 500/500 [00:00<00:00, 72653.80it/s]
# 100%|██████████| 500/500 [00:00<00:00, 55418.64it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 0it [00:00, ?it/s]Warning: Repeated SMILES found in data, pickle file of split indices cannot distinguish entries and will not be generated.
# 276it [00:00, 81106.14it/s]
# Total size = 500 | train size = 400 | val size = 50 | test size = 50
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:00,  9.02it/s]
#  38%|███▊      | 3/8 [00:00<00:00, 10.07it/s]
#  50%|█████     | 4/8 [00:00<00:00,  9.61it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  9.72it/s]
#  75%|███████▌  | 6/8 [00:00<00:00,  8.96it/s]
#  88%|████████▊ | 7/8 [00:00<00:00,  8.51it/s]
# 100%|██████████| 8/8 [00:00<00:00,  8.17it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.706185
#  20%|██        | 1/5 [00:01<00:04,  1.15s/it]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:00,  7.32it/s]Loss = 6.5336e-01, PNorm = 34.0271, GNorm = 6.2554, lr_0 = 7.1875e-04
#
#  25%|██▌       | 2/8 [00:00<00:00,  7.07it/s]
#  38%|███▊      | 3/8 [00:00<00:00,  6.73it/s]
#  50%|█████     | 4/8 [00:00<00:00,  6.58it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  6.70it/s]
#  75%|███████▌  | 6/8 [00:00<00:00,  6.78it/s]
#  88%|████████▊ | 7/8 [00:01<00:00,  7.02it/s]
# 100%|██████████| 8/8 [00:01<00:00,  6.93it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.387877
#  40%|████      | 2/5 [00:02<00:03,  1.29s/it]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:00,  7.14it/s]
#  25%|██▌       | 2/8 [00:00<00:00,  6.55it/s]
#  38%|███▊      | 3/8 [00:00<00:00,  6.86it/s]Loss = 4.3137e-01, PNorm = 34.0799, GNorm = 5.1803, lr_0 = 6.1897e-04
#
#  50%|█████     | 4/8 [00:00<00:00,  7.19it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  7.08it/s]
#  75%|███████▌  | 6/8 [00:00<00:00,  7.19it/s]
#  88%|████████▊ | 7/8 [00:00<00:00,  7.21it/s]
# 100%|██████████| 8/8 [00:01<00:00,  7.22it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.432342
#  60%|██████    | 3/5 [00:03<00:02,  1.27s/it]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:01,  6.58it/s]
#  25%|██▌       | 2/8 [00:00<00:00,  6.22it/s]
#  38%|███▊      | 3/8 [00:00<00:00,  6.57it/s]
#  50%|█████     | 4/8 [00:00<00:00,  7.14it/s]
#  62%|██████▎   | 5/8 [00:00<00:00,  7.84it/s]Loss = 4.0926e-01, PNorm = 34.1025, GNorm = 6.6010, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00,  8.37it/s]
#  88%|████████▊ | 7/8 [00:01<00:00,  5.38it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.345148
#  80%|████████  | 4/5 [00:05<00:01,  1.30s/it]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00, 11.57it/s]
#  50%|█████     | 4/8 [00:00<00:00, 10.71it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 10.93it/s]Loss = 3.1846e-01, PNorm = 34.1099, GNorm = 1.1095, lr_0 = 1.0000e-04
#
# 100%|██████████| 8/8 [00:00<00:00, 11.14it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.262283
# 100%|██████████| 5/5 [00:06<00:00,  1.20s/it]
# Model 0 best validation rmse = 1.262283 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 0 test rmse = 1.657099
# Ensemble test rmse = 1.657099
# 1-fold cross validation
# 	Seed 0 ==> test rmse = 1.657099
# Overall test rmse = 1.657099 +/- 0.000000
# Elapsed time = 0:00:07

# %%
arguments = [
    '--data_path', 'data/regression.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'test_checkpoints_transfer',
    '--epochs', '5',
    '--checkpoint_frzn', 'test_checkpoints_transfer/fold_0/model_0/model.pt'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-8f687a13-fd1d-4bb6-bf15-8368444c40f1.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': 'test_checkpoints_transfer/fold_0/model_0/model.pt',
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/regression.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 5,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'test_checkpoints_transfer',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['logSolubility'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Setting molecule featurization parameters to default.
# Loading data
# 500it [00:00, 109203.92it/s]
# 100%|██████████| 500/500 [00:00<00:00, 83936.44it/s]
# 100%|██████████| 500/500 [00:00<00:00, 99447.65it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# Total size = 500 | train size = 400 | val size = 50 | test size = 50
# Fitting scaler
# Building model 0
# Loading and freezing parameters from test_checkpoints_transfer/fold_0/model_0/model.pt.
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of unfrozen parameters = 90,601
# Total number of parameters = 355,201
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
#   0%|          | 0/5 [00:00<?, ?it/s]Epoch 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [00:00<00:00, 24.62it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 24.17it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.297117
#  20%|██        | 1/5 [00:00<00:01,  2.05it/s]Epoch 1
#
#   0%|          | 0/8 [00:00<?, ?it/s]Loss = 3.4231e-01, PNorm = 34.0887, GNorm = 2.9127, lr_0 = 7.1875e-04
#
#  38%|███▊      | 3/8 [00:00<00:00, 23.49it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 23.03it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.315881
#  40%|████      | 2/5 [00:00<00:01,  2.19it/s]Epoch 2
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [00:00<00:00, 23.14it/s]Loss = 3.2340e-01, PNorm = 34.1111, GNorm = 2.3180, lr_0 = 6.1897e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 23.50it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.287416
#  60%|██████    | 3/5 [00:01<00:00,  2.07it/s]Epoch 3
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [00:00<00:00, 22.48it/s]Loss = 3.2418e-01, PNorm = 34.1173, GNorm = 1.4311, lr_0 = 2.3714e-04
#
#  75%|███████▌  | 6/8 [00:00<00:00, 22.40it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.276664
#  80%|████████  | 4/5 [00:01<00:00,  2.01it/s]Epoch 4
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [00:00<00:00, 23.35it/s]
#  75%|███████▌  | 6/8 [00:00<00:00, 22.20it/s]Loss = 2.9644e-01, PNorm = 34.1190, GNorm = 0.9774, lr_0 = 1.0000e-04
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                      Validation rmse = 1.261734
# 100%|██████████| 5/5 [00:02<00:00,  2.02it/s]
# Model 0 best validation rmse = 1.261734 on epoch 4
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Model 0 test rmse = 1.561036
# Ensemble test rmse = 1.561036
# 1-fold cross validation
# 	Seed 0 ==> test rmse = 1.561036
# Overall test rmse = 1.561036 +/- 0.000000
# Elapsed time = 0:00:03

# %%
arguments = [
    '--test_path', 'test_checkpoints_transfer/fold_0/test_smiles.csv',
    '--preds_path', 'test_preds_transfer.csv',
    '--checkpoint_dir', 'test_checkpoints_transfer',
]

args = chemprop.args.PredictArgs().parse_args(arguments)
preds = chemprop.train.make_predictions(args=args)
# Out:
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 50it [00:00, 110667.65it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80381.45it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating SMILES
# Test size = 50
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.81it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# Saving predictions to test_preds_transfer.csv
# Elapsed time = 0:00:01
